# %% [markdown]
# # **SEL-NNML QMC Random Search (QMC-RS) Tuning - UCI Cleveland Heart Disease Dataset**
#
# This notebook implements `Stacking Ensemble Learning with a Neural Network Meta-Learner (SEL-NNML)` model on the `UCI Cleveland Heart Disease Dataset (UCHDD)`.

# %% [markdown]
# ## **0. Global Configuration**

# %%
# Random state for reproducibility
RANDOM_STATE = 42

# Data splitting configuration
TEST_SIZE = 0.2

# Cross-validation configuration
CV_FOLDS = 5

# Hyperparameter tuning configuration
OPTIMIZATION_ITERATIONS = 100
OPTIMIZATION_METRIC = 'accuracy'

# Parallel processing configuration
N_JOBS = -1 

# Dataset configuration
DATASET_PATH = '../../datasets/processed/ds2_uci_heart_clean.csv'
TARGET_COLUMN = 'num'

print("Global configuration loaded successfully!")
print(f"Random State: {RANDOM_STATE}")
print(f"Test Size: {TEST_SIZE}")
print(f"CV Folds: {CV_FOLDS}")
print(f"Optimization Iterations: {OPTIMIZATION_ITERATIONS}")
print(f"Optimization Metric: {OPTIMIZATION_METRIC}")
# Out:
# Global configuration loaded successfully!
# Random State: 42
# Test Size: 0.2
# CV Folds: 5
# Optimization Iterations: 100
# Optimization Metric: accuracy

# %% [markdown]
# ## **1. Import Library**

# %%
import pandas as pd
import numpy as np
np.random.seed(RANDOM_STATE)
import matplotlib.pyplot as plt
import optuna as opt
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import StackingClassifier

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

# %% [markdown]
# ## **2. Load Dataset**

# %%
df = pd.read_csv(DATASET_PATH)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            297 non-null    int64
#  1   sex            297 non-null    bool
#  2   trestbps       297 non-null    int64
#  3   chol           297 non-null    int64
#  4   fbs            297 non-null    bool
#  5   thalach        297 non-null    int64
#  6   exang          297 non-null    bool
#  7   oldpeak        297 non-null    float64
#  8   num            297 non-null    bool
#  9   cp_2           297 non-null    bool
#  10  cp_3           297 non-null    bool
#  11  cp_4           297 non-null    bool
#  12  restecg_1      297 non-null    bool
#  13  restecg_2      297 non-null    bool
#  14  slope_2        297 non-null    bool
#  15  slope_3        297 non-null    bool
#  16  ca_1.0         297 non-null    bool
#  17  ca_2.0         297 non-null    bool
#  18  ca_3.0         297 non-null    bool
#  19  thal_6.0       297 non-null    bool
#  20  thal_7.0       297 non-null    bool
#  21  cp_4_thal_7.0  297 non-null    bool
#  22  cp_4_exang     297 non-null    bool
# dtypes: bool(18), float64(1), int64(4)
# memory usage: 17.0 KB
#      age    sex  trestbps  chol    fbs  thalach  exang  oldpeak    num   cp_2  \
# 0     63   True       145   233   True      150  False      2.3  False  False
# 1     67   True       160   286  False      108   True      1.5   True  False
# 2     67   True       120   229  False      129   True      2.6   True  False
# 3     37   True       130   250  False      187  False      3.5  False  False
# 4     41  False       130   204  False      172  False      1.4  False   True
# ..   ...    ...       ...   ...    ...      ...    ...      ...    ...    ...
# 292   57  False       140   241  False      123   True      0.2   True  False
# 293   45   True       110   264  False      132  False      1.2   True  False
# 294   68   True       144   193   True      141  False      3.4   True  False
# 295   57   True       130   131  False      115   True      1.2   True  False
# 296   57  False       130   236  False      174  False      0.0   True   True
#
#      ...  restecg_2  slope_2  slope_3  ca_1.0  ca_2.0  ca_3.0  thal_6.0  \
# 0    ...       True    False     True   False   False   False      True
# 1    ...       True     True    False   False   False    True     False
# 2    ...       True     True    False   False    True   False     False
# 3    ...      False    False     True   False   False   False     False
# 4    ...       True    False    False   False   False   False     False
# ..   ...        ...      ...      ...     ...     ...     ...       ...
# 292  ...      False     True    False   False   False   False     False
# 293  ...      False     True    False   False   False   False     False
# 294  ...      False     True    False   False    True   False     False
# 295  ...      False     True    False    True   False   False     False
# 296  ...       True     True    False    True   False   False     False
#
#      thal_7.0  cp_4_thal_7.0  cp_4_exang
# 0       False          False       False
# 1       False          False        True
# 2        True           True        True
# 3       False          False       False
# 4       False          False       False
# ..        ...            ...         ...
# 292      True           True        True
# 293      True          False       False
# 294      True           True       False
# 295      True           True        True
# 296     False          False       False
#
# [297 rows x 23 columns]

# %% [markdown]
# ## **3. Data Preparation**

# %% [markdown]
# - Split the data into desired training and testing
# - After that, Scaling the data using Min-Max Normalization

# %%
# Split dataset
X = df.drop(columns=[TARGET_COLUMN])
y = df[TARGET_COLUMN]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

# %%
# Min-Max Scaling
# Separate numeric and boolean columns
num_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
bool_cols = X_train.select_dtypes(include=['bool', 'uint8']).columns  # includes one-hot from get_dummies

# Initialize scaler and fit_transform only on numeric data
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train[num_cols])
X_test_scaled = scaler.transform(X_test[num_cols])

# Convert back to DataFrame
X_train_scaled = pd.DataFrame(X_train_scaled, columns=num_cols, index=X_train.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=num_cols, index=X_test.index)

# Concatenate back with boolean features (without modification)
X_train = pd.concat([X_train_scaled, X_train[bool_cols]], axis=1)
X_test = pd.concat([X_test_scaled, X_test[bool_cols]], axis=1)

# %% [markdown]
# ## **4. Base Model Hyperparameter Tuning with QMC-RS and Cross Validation**

# %%
# Base Model Hyperparameter Tuning with QMC-RS and CV Function
def base_model_tuning(model_name, x_train, y_train, iterations=100, metric_compare='accuracy'):
    if model_name == 'Logistic Regression':
        def objective(trial):
            solver = trial.suggest_categorical('solver', ['lbfgs', 'newton-cg', 'newton-cholesky', 'sag'])
            C = trial.suggest_float('C', 1e-4, 10, log=True)
            model = LogisticRegression(solver=solver, C=C, max_iter=1000, random_state=RANDOM_STATE, n_jobs=N_JOBS)
            return cross_val_score(model, x_train, y_train, cv=CV_FOLDS, scoring=metric_compare, n_jobs=N_JOBS).mean()
        
        study = opt.create_study(study_name='Random Fine Tuning: Logistic Regression', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
        study.optimize(objective, n_trials=iterations, n_jobs=1, show_progress_bar=True)
        best_params = study.best_params
        model = LogisticRegression(**best_params, max_iter=1000, random_state=RANDOM_STATE, n_jobs=N_JOBS)
    
    elif model_name == 'Decision Tree':
        def objective(trial):
            criterion = trial.suggest_categorical('criterion', ['gini', 'entropy', 'log_loss'])
            max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
            max_depth = trial.suggest_int('max_depth', 3, 10)
            min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
            min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
            model = DecisionTreeClassifier(criterion=criterion, max_features=max_features, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf, random_state=RANDOM_STATE)
            return cross_val_score(model, x_train, y_train, cv=CV_FOLDS, scoring=metric_compare, n_jobs=N_JOBS).mean()

        study = opt.create_study(study_name='Random Fine Tuning: Decision Tree', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
        study.optimize(objective, n_trials=iterations, n_jobs=1, show_progress_bar=True)
        best_params = study.best_params
        model = DecisionTreeClassifier(**best_params, random_state=RANDOM_STATE)
        
    elif model_name == 'Random Forest':
        def objective(trial):
            criterion = trial.suggest_categorical('criterion', ['gini', 'entropy', 'log_loss'])
            max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
            n_estimators = trial.suggest_int('n_estimators', 10, 100)
            max_depth = trial.suggest_int('max_depth', 3, 10)
            min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
            min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
            model = RandomForestClassifier(criterion=criterion, max_features=max_features, n_estimators=n_estimators, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf, random_state=RANDOM_STATE, n_jobs=N_JOBS)
            return cross_val_score(model, x_train, y_train, cv=CV_FOLDS, scoring=metric_compare, n_jobs=N_JOBS).mean()
        
        study = opt.create_study(study_name='Random Fine Tuning: Random Forest', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
        study.optimize(objective, n_trials=iterations, n_jobs=1, show_progress_bar=True)
        best_params = study.best_params
        model = RandomForestClassifier(**best_params, random_state=RANDOM_STATE, n_jobs=N_JOBS)
    
    elif model_name == 'K-Nearest Neighbors':
        def objective(trial):
            algorithm = trial.suggest_categorical('algorithm', ['ball_tree', 'kd_tree', 'brute'])
            n_neighbors = trial.suggest_int('n_neighbors', 3, 50)
            p = trial.suggest_int('p', 1, 2)
            model = KNeighborsClassifier(weights='uniform', algorithm=algorithm, n_neighbors=n_neighbors, p=p, n_jobs=N_JOBS)
            return cross_val_score(model, x_train, y_train, cv=CV_FOLDS, scoring=metric_compare, n_jobs=N_JOBS).mean()
        
        study = opt.create_study(study_name='Random Fine Tuning: K-Nearest Neighbors', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
        study.optimize(objective, n_trials=iterations, n_jobs=1, show_progress_bar=True)
        best_params = study.best_params
        model = KNeighborsClassifier(**best_params, weights='uniform', n_jobs=N_JOBS)
    
    elif model_name == 'Support Vector Machine':
        def objective(trial):
            kernel = trial.suggest_categorical('kernel', ['rbf', 'sigmoid', 'poly'])
            C = trial.suggest_float('C', 1e-4, 1e-2, log=True)
            degree = trial.suggest_int('degree', 2, 5) if kernel == 'poly' else 3
            model = SVC(kernel=kernel, gamma='scale', C=C, degree=degree, random_state=RANDOM_STATE)
            return cross_val_score(model, x_train, y_train, cv=CV_FOLDS, scoring=metric_compare, n_jobs=N_JOBS).mean()
        
        study = opt.create_study(study_name='Random Fine Tuning: Support Vector Machine', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
        study.optimize(objective, n_trials=iterations, n_jobs=1, show_progress_bar=True)
        best_params = study.best_params
        model = SVC(**best_params, gamma='scale', random_state=RANDOM_STATE)
    
    elif model_name == 'AdaBoost':
        def objective(trial):
            n_estimators = trial.suggest_int('n_estimators', 10, 100)
            learning_rate = trial.suggest_float('learning_rate', 0.001, 1.0, log=True)
            model = AdaBoostClassifier(n_estimators=n_estimators, learning_rate=learning_rate, random_state=RANDOM_STATE)
            return cross_val_score(model, x_train, y_train, cv=CV_FOLDS, scoring=metric_compare, n_jobs=N_JOBS).mean()
        
        study = opt.create_study(study_name='Random Fine Tuning: AdaBoost', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
        study.optimize(objective, n_trials=iterations, n_jobs=1, show_progress_bar=True)
        best_params = study.best_params
        model = AdaBoostClassifier(**best_params, random_state=RANDOM_STATE)
        
    elif model_name == 'Gradient Boosting':
        def objective(trial):
            max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
            n_estimators = trial.suggest_int('n_estimators', 10, 100)
            learning_rate = trial.suggest_float('learning_rate', 0.001, 0.1, log=True)
            max_depth = trial.suggest_int('max_depth', 3, 10)
            min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
            min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
            subsample = trial.suggest_float('subsample', 0.5, 1.0)
            model = GradientBoostingClassifier(criterion='friedman_mse', loss='log_loss', max_features=max_features, n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf, subsample=subsample, random_state=RANDOM_STATE)
            return cross_val_score(model, x_train, y_train, cv=CV_FOLDS, scoring=metric_compare, n_jobs=N_JOBS).mean()
        
        study = opt.create_study(study_name='QMC Random Fine Tuning: Gradient Boosting', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
        study.optimize(objective, n_trials=iterations, n_jobs=1, show_progress_bar=True)
        best_params = study.best_params
        model = GradientBoostingClassifier(**best_params, criterion='friedman_mse', loss='log_loss', random_state=RANDOM_STATE)
    
    print(f'\nBest Hyperparameters for {model_name}: (Using QMCSampler)')
    print(best_params)
    
    return model

# %%
# Begin timing base models training
base_models_training_start = time.time()

# %% [markdown]
# ### **4.1 Logistic Regression Hyperparameter Tuning**

# %%
logistic_regression = base_model_tuning('Logistic Regression', X_train, y_train, iterations=OPTIMIZATION_ITERATIONS, metric_compare=OPTIMIZATION_METRIC)
# Out:
# C:\Users\azhar\AppData\Local\Temp\ipykernel_23760\1802863948.py:10: ExperimentalWarning: QMCSampler is experimental (supported from v3.0.0). The interface can change in the future.
#   study = opt.create_study(study_name='Random Fine Tuning: Logistic Regression', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
# [I 2025-10-03 10:48:52,215] A new study created in memory with name: Random Fine Tuning: Logistic Regression
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-03 10:48:55,065] Trial 0 finished with value: 0.52322695035461 and parameters: {'solver': 'newton-cg', 'C': 0.0006026889128682511}. Best is trial 0 with value: 0.52322695035461.
# [W 2025-10-03 10:48:55,083] The parameter `solver` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:48:57,512] Trial 1 finished with value: 0.52322695035461 and parameters: {'solver': 'newton-cholesky', 'C': 0.00010000000000000009}. Best is trial 0 with value: 0.52322695035461.
# [W 2025-10-03 10:48:57,516] The parameter `solver` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:48:59,688] Trial 2 finished with value: 0.8056737588652483 and parameters: {'solver': 'newton-cholesky', 'C': 0.0316227766016838}. Best is trial 2 with value: 0.8056737588652483.
# [W 2025-10-03 10:48:59,690] The parameter `solver` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:01,754] Trial 3 finished with value: 0.8395390070921985 and parameters: {'solver': 'sag', 'C': 0.5623413251903494}. Best is trial 3 with value: 0.8395390070921985.
# [W 2025-10-03 10:49:01,754] The parameter `solver` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:01,792] Trial 4 finished with value: 0.7086879432624114 and parameters: {'solver': 'sag', 'C': 0.0017782794100389236}. Best is trial 3 with value: 0.8395390070921985.
# [W 2025-10-03 10:49:01,794] The parameter `solver` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:01,829] Trial 5 finished with value: 0.7973404255319149 and parameters: {'solver': 'sag', 'C': 0.007498942093324564}. Best is trial 3 with value: 0.8395390070921985.
# [W 2025-10-03 10:49:01,829] The parameter `solver` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:01,866] Trial 6 finished with value: 0.839627659574468 and parameters: {'solver': 'lbfgs', 'C': 2.371373705661655}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:01,866] The parameter `solver` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:01,904] Trial 7 finished with value: 0.797340425531915 and parameters: {'solver': 'newton-cg', 'C': 0.13335214321633232}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:01,904] The parameter `solver` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:01,941] Trial 8 finished with value: 0.52322695035461 and parameters: {'solver': 'newton-cg', 'C': 0.00042169650342858235}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:01,941] The parameter `solver` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:01,978] Trial 9 finished with value: 0.52322695035461 and parameters: {'solver': 'newton-cg', 'C': 0.000865964323360066}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:01,978] The parameter `solver` in Trial#10 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,035] Trial 10 finished with value: 0.8141843971631205 and parameters: {'solver': 'newton-cholesky', 'C': 0.27384196342643613}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:02,035] The parameter `solver` in Trial#11 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,072] Trial 11 finished with value: 0.8311170212765958 and parameters: {'solver': 'lbfgs', 'C': 4.8696752516586255}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:02,072] The parameter `solver` in Trial#12 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,109] Trial 12 finished with value: 0.8098404255319149 and parameters: {'solver': 'newton-cg', 'C': 0.015399265260594926}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:02,109] The parameter `solver` in Trial#13 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,167] Trial 13 finished with value: 0.784663120567376 and parameters: {'solver': 'newton-cholesky', 'C': 0.0036517412725483775}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:02,168] The parameter `solver` in Trial#14 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,204] Trial 14 finished with value: 0.8394503546099292 and parameters: {'solver': 'sag', 'C': 1.1547819846894576}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:02,206] The parameter `solver` in Trial#15 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,242] Trial 15 finished with value: 0.797340425531915 and parameters: {'solver': 'newton-cg', 'C': 0.06493816315762112}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:02,242] The parameter `solver` in Trial#16 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,299] Trial 16 finished with value: 0.52322695035461 and parameters: {'solver': 'newton-cholesky', 'C': 0.0002053525026457149}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:02,299] The parameter `solver` in Trial#17 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,336] Trial 17 finished with value: 0.52322695035461 and parameters: {'solver': 'lbfgs', 'C': 0.0002942727176209287}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:02,337] The parameter `solver` in Trial#18 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,373] Trial 18 finished with value: 0.7930851063829787 and parameters: {'solver': 'lbfgs', 'C': 0.0930572040929699}. Best is trial 6 with value: 0.839627659574468.
# [W 2025-10-03 10:49:02,375] The parameter `solver` in Trial#19 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,410] Trial 19 finished with value: 0.8437943262411348 and parameters: {'solver': 'sag', 'C': 1.6548170999431808}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,412] The parameter `solver` in Trial#20 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,447] Trial 20 finished with value: 0.788918439716312 and parameters: {'solver': 'lbfgs', 'C': 0.005232991146814949}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,449] The parameter `solver` in Trial#21 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,483] Trial 21 finished with value: 0.8099290780141845 and parameters: {'solver': 'sag', 'C': 0.022067340690845896}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,485] The parameter `solver` in Trial#22 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,520] Trial 22 finished with value: 0.826950354609929 and parameters: {'solver': 'sag', 'C': 6.978305848598657}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,522] The parameter `solver` in Trial#23 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,557] Trial 23 finished with value: 0.8352836879432625 and parameters: {'solver': 'newton-cg', 'C': 0.3924189758484537}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,557] The parameter `solver` in Trial#24 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,594] Trial 24 finished with value: 0.6033687943262411 and parameters: {'solver': 'lbfgs', 'C': 0.0012409377607517208}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,594] The parameter `solver` in Trial#25 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,632] Trial 25 finished with value: 0.52322695035461 and parameters: {'solver': 'sag', 'C': 0.0006042963902381332}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,633] The parameter `solver` in Trial#26 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,689] Trial 26 finished with value: 0.8016843971631206 and parameters: {'solver': 'newton-cholesky', 'C': 0.19109529749704401}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,690] The parameter `solver` in Trial#27 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,726] Trial 27 finished with value: 0.839627659574468 and parameters: {'solver': 'sag', 'C': 3.39820832894256}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,727] The parameter `solver` in Trial#28 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,762] Trial 28 finished with value: 0.7972517730496455 and parameters: {'solver': 'newton-cholesky', 'C': 0.010746078283213176}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,764] The parameter `solver` in Trial#29 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,799] Trial 29 finished with value: 0.746631205673759 and parameters: {'solver': 'newton-cg', 'C': 0.0025482967479793462}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,801] The parameter `solver` in Trial#30 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,836] Trial 30 finished with value: 0.8395390070921985 and parameters: {'solver': 'lbfgs', 'C': 0.8058421877614811}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,837] The parameter `solver` in Trial#31 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,873] Trial 31 finished with value: 0.8015070921985815 and parameters: {'solver': 'newton-cholesky', 'C': 0.045315836376008195}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,874] The parameter `solver` in Trial#32 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,910] Trial 32 finished with value: 0.52322695035461 and parameters: {'solver': 'lbfgs', 'C': 0.00014330125702369644}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,910] The parameter `solver` in Trial#33 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,946] Trial 33 finished with value: 0.52322695035461 and parameters: {'solver': 'newton-cg', 'C': 0.00017154378963428796}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,948] The parameter `solver` in Trial#34 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:02,983] Trial 34 finished with value: 0.7972517730496455 and parameters: {'solver': 'newton-cholesky', 'C': 0.05424690937011324}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:02,984] The parameter `solver` in Trial#35 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,020] Trial 35 finished with value: 0.8437056737588653 and parameters: {'solver': 'newton-cg', 'C': 0.9646616199111994}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,020] The parameter `solver` in Trial#36 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,058] Trial 36 finished with value: 0.7678191489361701 and parameters: {'solver': 'newton-cg', 'C': 0.0030505278902670284}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,061] The parameter `solver` in Trial#37 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,095] Trial 37 finished with value: 0.8098404255319149 and parameters: {'solver': 'newton-cg', 'C': 0.01286396944936975}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,095] The parameter `solver` in Trial#38 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,132] Trial 38 finished with value: 0.839627659574468 and parameters: {'solver': 'newton-cg', 'C': 4.067944321083045}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,133] The parameter `solver` in Trial#39 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,169] Trial 39 finished with value: 0.8016843971631206 and parameters: {'solver': 'lbfgs', 'C': 0.22875732003183954}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,171] The parameter `solver` in Trial#40 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,206] Trial 40 finished with value: 0.52322695035461 and parameters: {'solver': 'newton-cg', 'C': 0.0007233941627366753}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,207] The parameter `solver` in Trial#41 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,244] Trial 41 finished with value: 0.6538120567375887 and parameters: {'solver': 'lbfgs', 'C': 0.0014855080171727755}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,245] The parameter `solver` in Trial#42 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,281] Trial 42 finished with value: 0.835372340425532 and parameters: {'solver': 'newton-cg', 'C': 0.469758881670649}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,282] The parameter `solver` in Trial#43 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,318] Trial 43 finished with value: 0.826950354609929 and parameters: {'solver': 'sag', 'C': 8.353625469578262}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,318] The parameter `solver` in Trial#44 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,355] Trial 44 finished with value: 0.8099290780141845 and parameters: {'solver': 'newton-cg', 'C': 0.026416483203860926}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,356] The parameter `solver` in Trial#45 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,391] Trial 45 finished with value: 0.8015070921985817 and parameters: {'solver': 'newton-cg', 'C': 0.00626433536656886}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,391] The parameter `solver` in Trial#46 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,428] Trial 46 finished with value: 0.8437943262411348 and parameters: {'solver': 'newton-cg', 'C': 1.9809567785503366}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,429] The parameter `solver` in Trial#47 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,465] Trial 47 finished with value: 0.7930851063829787 and parameters: {'solver': 'sag', 'C': 0.11139738599948026}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,465] The parameter `solver` in Trial#48 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,502] Trial 48 finished with value: 0.52322695035461 and parameters: {'solver': 'sag', 'C': 0.0003522694651473105}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,502] The parameter `solver` in Trial#49 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,538] Trial 49 finished with value: 0.52322695035461 and parameters: {'solver': 'lbfgs', 'C': 0.0002458244068920199}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,538] The parameter `solver` in Trial#50 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,575] Trial 50 finished with value: 0.7930851063829787 and parameters: {'solver': 'newton-cholesky', 'C': 0.07773650302387758}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,576] The parameter `solver` in Trial#51 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,612] Trial 51 finished with value: 0.8352836879432625 and parameters: {'solver': 'newton-cholesky', 'C': 1.3823722273579002}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,613] The parameter `solver` in Trial#52 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,669] Trial 52 finished with value: 0.7887411347517731 and parameters: {'solver': 'newton-cholesky', 'C': 0.004371444812611091}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,670] The parameter `solver` in Trial#53 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,706] Trial 53 finished with value: 0.8056737588652483 and parameters: {'solver': 'newton-cg', 'C': 0.018434229924091116}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,707] The parameter `solver` in Trial#54 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,742] Trial 54 finished with value: 0.8312056737588653 and parameters: {'solver': 'newton-cholesky', 'C': 5.829415347136073}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,742] The parameter `solver` in Trial#55 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,779] Trial 55 finished with value: 0.8226063829787235 and parameters: {'solver': 'lbfgs', 'C': 0.32781211513934566}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,781] The parameter `solver` in Trial#56 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,816] Trial 56 finished with value: 0.5570921985815603 and parameters: {'solver': 'newton-cg', 'C': 0.001036632928437698}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,817] The parameter `solver` in Trial#57 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,853] Trial 57 finished with value: 0.52322695035461 and parameters: {'solver': 'newton-cg', 'C': 0.0005048065716667473}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,855] The parameter `solver` in Trial#58 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,889] Trial 58 finished with value: 0.801595744680851 and parameters: {'solver': 'newton-cholesky', 'C': 0.15963385442879416}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,891] The parameter `solver` in Trial#59 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,926] Trial 59 finished with value: 0.839627659574468 and parameters: {'solver': 'sag', 'C': 2.8387359647587527}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,927] The parameter `solver` in Trial#60 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:03,963] Trial 60 finished with value: 0.7930851063829787 and parameters: {'solver': 'lbfgs', 'C': 0.008976871324473142}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:03,965] The parameter `solver` in Trial#61 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,000] Trial 61 finished with value: 0.73395390070922 and parameters: {'solver': 'newton-cholesky', 'C': 0.002128751661796374}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,002] The parameter `solver` in Trial#62 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,037] Trial 62 finished with value: 0.8395390070921985 and parameters: {'solver': 'lbfgs', 'C': 0.6731703824144981}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,038] The parameter `solver` in Trial#63 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,075] Trial 63 finished with value: 0.8099290780141845 and parameters: {'solver': 'sag', 'C': 0.03785515249258631}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,077] The parameter `solver` in Trial#64 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,112] Trial 64 finished with value: 0.52322695035461 and parameters: {'solver': 'lbfgs', 'C': 0.00011970850304957301}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,113] The parameter `solver` in Trial#65 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,148] Trial 65 finished with value: 0.52322695035461 and parameters: {'solver': 'lbfgs', 'C': 0.00013097472643005907}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,149] The parameter `solver` in Trial#66 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,186] Trial 66 finished with value: 0.8015070921985815 and parameters: {'solver': 'lbfgs', 'C': 0.04141784514364404}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,188] The parameter `solver` in Trial#67 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,224] Trial 67 finished with value: 0.8395390070921985 and parameters: {'solver': 'sag', 'C': 0.7365250122712284}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,225] The parameter `solver` in Trial#68 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,261] Trial 68 finished with value: 0.738209219858156 and parameters: {'solver': 'lbfgs', 'C': 0.0023290965924605465}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,263] The parameter `solver` in Trial#69 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,299] Trial 69 finished with value: 0.7972517730496455 and parameters: {'solver': 'sag', 'C': 0.009821718891880384}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,300] The parameter `solver` in Trial#70 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,337] Trial 70 finished with value: 0.839627659574468 and parameters: {'solver': 'sag', 'C': 3.105900223624704}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,338] The parameter `solver` in Trial#71 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,373] Trial 71 finished with value: 0.8016843971631206 and parameters: {'solver': 'newton-cholesky', 'C': 0.17465760476621184}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,374] The parameter `solver` in Trial#72 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# ...
# [W 2025-10-03 10:49:04,523] The parameter `solver` in Trial#76 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,559] Trial 76 finished with value: 0.8056737588652483 and parameters: {'solver': 'lbfgs', 'C': 0.02016914554730331}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,561] The parameter `solver` in Trial#77 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,596] Trial 77 finished with value: 0.788918439716312 and parameters: {'solver': 'newton-cg', 'C': 0.004782858141653791}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,597] The parameter `solver` in Trial#78 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,633] Trial 78 finished with value: 0.8352836879432625 and parameters: {'solver': 'lbfgs', 'C': 1.512472545310622}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,635] The parameter `solver` in Trial#79 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,670] Trial 79 finished with value: 0.7930851063829787 and parameters: {'solver': 'sag', 'C': 0.08505258154439958}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,671] The parameter `solver` in Trial#80 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,707] Trial 80 finished with value: 0.52322695035461 and parameters: {'solver': 'sag', 'C': 0.00026895987855750467}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,707] The parameter `solver` in Trial#81 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,743] Trial 81 finished with value: 0.52322695035461 and parameters: {'solver': 'lbfgs', 'C': 0.00038542288686231087}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,745] The parameter `solver` in Trial#82 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,780] Trial 82 finished with value: 0.797340425531915 and parameters: {'solver': 'newton-cholesky', 'C': 0.12188141848422895}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,782] The parameter `solver` in Trial#83 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,817] Trial 83 finished with value: 0.8437943262411348 and parameters: {'solver': 'sag', 'C': 2.167392169568416}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,819] The parameter `solver` in Trial#84 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,854] Trial 84 finished with value: 0.7973404255319149 and parameters: {'solver': 'lbfgs', 'C': 0.006853895838650084}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,856] The parameter `solver` in Trial#85 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,891] Trial 85 finished with value: 0.8056737588652483 and parameters: {'solver': 'lbfgs', 'C': 0.028902639100224517}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,892] The parameter `solver` in Trial#86 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,928] Trial 86 finished with value: 0.8311170212765958 and parameters: {'solver': 'newton-cg', 'C': 9.139816994654893}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,929] The parameter `solver` in Trial#87 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:04,965] Trial 87 finished with value: 0.8395390070921985 and parameters: {'solver': 'newton-cholesky', 'C': 0.5139696800771514}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:04,967] The parameter `solver` in Trial#88 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,002] Trial 88 finished with value: 0.6832446808510638 and parameters: {'solver': 'newton-cholesky', 'C': 0.001625314837311866}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:05,003] The parameter `solver` in Trial#89 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,039] Trial 89 finished with value: 0.52322695035461 and parameters: {'solver': 'newton-cg', 'C': 0.0007914755439411164}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:05,039] The parameter `solver` in Trial#90 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,076] Trial 90 finished with value: 0.8058510638297871 and parameters: {'solver': 'sag', 'C': 0.2502865431174607}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:05,077] The parameter `solver` in Trial#91 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,113] Trial 91 finished with value: 0.839627659574468 and parameters: {'solver': 'newton-cg', 'C': 4.450794062355996}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:05,114] The parameter `solver` in Trial#92 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,150] Trial 92 finished with value: 0.8098404255319149 and parameters: {'solver': 'newton-cg', 'C': 0.014074646633398432}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:05,151] The parameter `solver` in Trial#93 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,186] Trial 93 finished with value: 0.776241134751773 and parameters: {'solver': 'sag', 'C': 0.0033376246942920405}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:05,188] The parameter `solver` in Trial#94 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,223] Trial 94 finished with value: 0.8394503546099292 and parameters: {'solver': 'newton-cg', 'C': 1.0554496008786018}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:05,224] The parameter `solver` in Trial#95 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,260] Trial 95 finished with value: 0.7930851063829787 and parameters: {'solver': 'newton-cholesky', 'C': 0.05935229272296987}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:05,261] The parameter `solver` in Trial#96 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,297] Trial 96 finished with value: 0.52322695035461 and parameters: {'solver': 'lbfgs', 'C': 0.00018768842935762206}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:05,299] The parameter `solver` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,334] Trial 97 finished with value: 0.52322695035461 and parameters: {'solver': 'newton-cg', 'C': 0.00015678788438269704}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:05,336] The parameter `solver` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,370] Trial 98 finished with value: 0.7972517730496455 and parameters: {'solver': 'newton-cholesky', 'C': 0.04958068241684656}. Best is trial 19 with value: 0.8437943262411348.
# [W 2025-10-03 10:49:05,371] The parameter `solver` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,408] Trial 99 finished with value: 0.8437056737588653 and parameters: {'solver': 'newton-cholesky', 'C': 0.8816830667755706}. Best is trial 19 with value: 0.8437943262411348.
#
# Best Hyperparameters for Logistic Regression: (Using QMCSampler)
# {'solver': 'sag', 'C': 1.6548170999431808}

# %% [markdown]
# ### **4.2 Decision Tree Hyperparameter Tuning**

# %%
decision_tree = base_model_tuning('Decision Tree', X_train, y_train, iterations=OPTIMIZATION_ITERATIONS, metric_compare=OPTIMIZATION_METRIC)
# Out:
# C:\Users\azhar\AppData\Local\Temp\ipykernel_23760\1802863948.py:25: ExperimentalWarning: QMCSampler is experimental (supported from v3.0.0). The interface can change in the future.
#   study = opt.create_study(study_name='Random Fine Tuning: Decision Tree', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
# [I 2025-10-03 10:49:05,423] A new study created in memory with name: Random Fine Tuning: Decision Tree
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-03 10:49:05,518] Trial 0 finished with value: 0.7085992907801418 and parameters: {'criterion': 'entropy', 'max_features': 'sqrt', 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 7}. Best is trial 0 with value: 0.7085992907801418.
# [W 2025-10-03 10:49:05,520] The parameter `criterion` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,521] The parameter `max_features` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,588] Trial 1 finished with value: 0.7129432624113476 and parameters: {'criterion': 'log_loss', 'max_features': 'sqrt', 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.7129432624113476.
# [W 2025-10-03 10:49:05,590] The parameter `criterion` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,592] The parameter `max_features` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,658] Trial 2 finished with value: 0.7296985815602837 and parameters: {'criterion': 'log_loss', 'max_features': None, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 2 with value: 0.7296985815602837.
# [W 2025-10-03 10:49:05,660] The parameter `criterion` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,661] The parameter `max_features` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,727] Trial 3 finished with value: 0.712677304964539 and parameters: {'criterion': 'log_loss', 'max_features': 'log2', 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 2 with value: 0.7296985815602837.
# [W 2025-10-03 10:49:05,730] The parameter `criterion` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,731] The parameter `max_features` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,745] Trial 4 finished with value: 0.725354609929078 and parameters: {'criterion': 'entropy', 'max_features': 'sqrt', 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 8}. Best is trial 2 with value: 0.7296985815602837.
# [W 2025-10-03 10:49:05,746] The parameter `criterion` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,747] The parameter `max_features` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,762] Trial 5 finished with value: 0.7338652482269503 and parameters: {'criterion': 'entropy', 'max_features': None, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 7}. Best is trial 5 with value: 0.7338652482269503.
# [W 2025-10-03 10:49:05,764] The parameter `criterion` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,764] The parameter `max_features` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,779] Trial 6 finished with value: 0.7171099290780142 and parameters: {'criterion': 'log_loss', 'max_features': 'log2', 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 5 with value: 0.7338652482269503.
# [W 2025-10-03 10:49:05,779] The parameter `criterion` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,779] The parameter `max_features` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,798] Trial 7 finished with value: 0.6829787234042553 and parameters: {'criterion': 'gini', 'max_features': None, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 9}. Best is trial 5 with value: 0.7338652482269503.
# [W 2025-10-03 10:49:05,800] The parameter `criterion` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,800] The parameter `max_features` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,815] Trial 8 finished with value: 0.712854609929078 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 5 with value: 0.7338652482269503.
# [W 2025-10-03 10:49:05,815] The parameter `criterion` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,815] The parameter `max_features` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,832] Trial 9 finished with value: 0.7043439716312057 and parameters: {'criterion': 'log_loss', 'max_features': None, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 10}. Best is trial 5 with value: 0.7338652482269503.
# [W 2025-10-03 10:49:05,832] The parameter `criterion` in Trial#10 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,832] The parameter `max_features` in Trial#10 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,849] Trial 10 finished with value: 0.7420212765957446 and parameters: {'criterion': 'log_loss', 'max_features': 'log2', 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 5}. Best is trial 10 with value: 0.7420212765957446.
# [W 2025-10-03 10:49:05,849] The parameter `criterion` in Trial#11 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,849] The parameter `max_features` in Trial#11 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,866] Trial 11 finished with value: 0.7040780141843971 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 7}. Best is trial 10 with value: 0.7420212765957446.
# [W 2025-10-03 10:49:05,866] The parameter `criterion` in Trial#12 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,866] The parameter `max_features` in Trial#12 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,883] Trial 12 finished with value: 0.7085106382978723 and parameters: {'criterion': 'entropy', 'max_features': None, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 10 with value: 0.7420212765957446.
# [W 2025-10-03 10:49:05,885] The parameter `criterion` in Trial#13 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,885] The parameter `max_features` in Trial#13 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,901] Trial 13 finished with value: 0.7167553191489362 and parameters: {'criterion': 'gini', 'max_features': None, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 10 with value: 0.7420212765957446.
# [W 2025-10-03 10:49:05,902] The parameter `criterion` in Trial#14 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,902] The parameter `max_features` in Trial#14 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,918] Trial 14 finished with value: 0.7210992907801417 and parameters: {'criterion': 'entropy', 'max_features': None, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 9}. Best is trial 10 with value: 0.7420212765957446.
# [W 2025-10-03 10:49:05,918] The parameter `criterion` in Trial#15 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,920] The parameter `max_features` in Trial#15 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,935] Trial 15 finished with value: 0.7256205673758865 and parameters: {'criterion': 'entropy', 'max_features': 'sqrt', 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 10 with value: 0.7420212765957446.
# [W 2025-10-03 10:49:05,935] The parameter `criterion` in Trial#16 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,935] The parameter `max_features` in Trial#16 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,952] Trial 16 finished with value: 0.725354609929078 and parameters: {'criterion': 'log_loss', 'max_features': None, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 6}. Best is trial 10 with value: 0.7420212765957446.
# [W 2025-10-03 10:49:05,952] The parameter `criterion` in Trial#17 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,952] The parameter `max_features` in Trial#17 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,969] Trial 17 finished with value: 0.7167553191489361 and parameters: {'criterion': 'log_loss', 'max_features': None, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 10 with value: 0.7420212765957446.
# [W 2025-10-03 10:49:05,969] The parameter `criterion` in Trial#18 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,969] The parameter `max_features` in Trial#18 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:05,986] Trial 18 finished with value: 0.750531914893617 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 10}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:05,988] The parameter `criterion` in Trial#19 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:05,988] The parameter `max_features` in Trial#19 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,004] Trial 19 finished with value: 0.712677304964539 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,006] The parameter `criterion` in Trial#20 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,006] The parameter `max_features` in Trial#20 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,021] Trial 20 finished with value: 0.725354609929078 and parameters: {'criterion': 'log_loss', 'max_features': 'log2', 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 8}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,021] The parameter `criterion` in Trial#21 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,024] The parameter `max_features` in Trial#21 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,038] Trial 21 finished with value: 0.6829787234042553 and parameters: {'criterion': 'gini', 'max_features': None, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 9}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,040] The parameter `criterion` in Trial#22 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,040] The parameter `max_features` in Trial#22 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,055] Trial 22 finished with value: 0.7001773049645391 and parameters: {'criterion': 'log_loss', 'max_features': 'log2', 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,055] The parameter `criterion` in Trial#23 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,055] The parameter `max_features` in Trial#23 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,072] Trial 23 finished with value: 0.7467198581560284 and parameters: {'criterion': 'entropy', 'max_features': None, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 6}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,073] The parameter `criterion` in Trial#24 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,073] The parameter `max_features` in Trial#24 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,090] Trial 24 finished with value: 0.6794326241134752 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,091] The parameter `criterion` in Trial#25 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,091] The parameter `max_features` in Trial#25 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,107] Trial 25 finished with value: 0.7042553191489361 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 6}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,107] The parameter `criterion` in Trial#26 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,107] The parameter `max_features` in Trial#26 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,125] Trial 26 finished with value: 0.7381205673758865 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,127] The parameter `criterion` in Trial#27 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,127] The parameter `max_features` in Trial#27 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,142] Trial 27 finished with value: 0.699645390070922 and parameters: {'criterion': 'gini', 'max_features': None, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 8}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,142] The parameter `criterion` in Trial#28 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,145] The parameter `max_features` in Trial#28 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,159] Trial 28 finished with value: 0.7169326241134752 and parameters: {'criterion': 'entropy', 'max_features': None, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,159] The parameter `criterion` in Trial#29 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,159] The parameter `max_features` in Trial#29 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,177] Trial 29 finished with value: 0.6958333333333334 and parameters: {'criterion': 'entropy', 'max_features': None, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,177] The parameter `criterion` in Trial#30 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,179] The parameter `max_features` in Trial#30 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,194] Trial 30 finished with value: 0.7040780141843971 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 7}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,194] The parameter `criterion` in Trial#31 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,194] The parameter `max_features` in Trial#31 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,211] Trial 31 finished with value: 0.7335106382978723 and parameters: {'criterion': 'log_loss', 'max_features': 'sqrt', 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,212] The parameter `criterion` in Trial#32 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,212] The parameter `max_features` in Trial#32 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,230] Trial 32 finished with value: 0.712854609929078 and parameters: {'criterion': 'log_loss', 'max_features': 'sqrt', 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 10}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,230] The parameter `criterion` in Trial#33 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,232] The parameter `max_features` in Trial#33 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,258] Trial 33 finished with value: 0.7085992907801418 and parameters: {'criterion': 'log_loss', 'max_features': 'sqrt', 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 8}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,260] The parameter `criterion` in Trial#34 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,260] The parameter `max_features` in Trial#34 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,276] Trial 34 finished with value: 0.7379432624113476 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,276] The parameter `criterion` in Trial#35 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,278] The parameter `max_features` in Trial#35 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,293] Trial 35 finished with value: 0.750531914893617 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 10}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,293] The parameter `criterion` in Trial#36 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,295] The parameter `max_features` in Trial#36 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,310] Trial 36 finished with value: 0.7124999999999999 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 18 with value: 0.750531914893617.
# [W 2025-10-03 10:49:06,310] The parameter `criterion` in Trial#37 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,310] The parameter `max_features` in Trial#37 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,328] Trial 37 finished with value: 0.7634751773049644 and parameters: {'criterion': 'entropy', 'max_features': 'sqrt', 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:06,328] The parameter `criterion` in Trial#38 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,328] The parameter `max_features` in Trial#38 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,345] Trial 38 finished with value: 0.750531914893617 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 6}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:06,346] The parameter `criterion` in Trial#39 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:06,346] The parameter `max_features` in Trial#39 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:06,362] Trial 39 finished with value: 0.7044326241134752 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:06,362] The parameter `criterion` in Trial#40 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# ...
# [W 2025-10-03 10:49:07,191] The parameter `criterion` in Trial#87 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,191] The parameter `max_features` in Trial#87 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,208] Trial 87 finished with value: 0.7381205673758865 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:07,208] The parameter `criterion` in Trial#88 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,210] The parameter `max_features` in Trial#88 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,225] Trial 88 finished with value: 0.7338652482269502 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 8}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:07,226] The parameter `criterion` in Trial#89 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,226] The parameter `max_features` in Trial#89 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,243] Trial 89 finished with value: 0.700177304964539 and parameters: {'criterion': 'entropy', 'max_features': 'sqrt', 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:07,244] The parameter `criterion` in Trial#90 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,244] The parameter `max_features` in Trial#90 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,261] Trial 90 finished with value: 0.7547872340425531 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 9}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:07,262] The parameter `criterion` in Trial#91 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,262] The parameter `max_features` in Trial#91 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,278] Trial 91 finished with value: 0.7256205673758864 and parameters: {'criterion': 'log_loss', 'max_features': None, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:07,278] The parameter `criterion` in Trial#92 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,278] The parameter `max_features` in Trial#92 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,295] Trial 92 finished with value: 0.7378546099290779 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 7}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:07,295] The parameter `criterion` in Trial#93 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,295] The parameter `max_features` in Trial#93 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,312] Trial 93 finished with value: 0.7337765957446809 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 10}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:07,312] The parameter `criterion` in Trial#94 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,312] The parameter `max_features` in Trial#94 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,329] Trial 94 finished with value: 0.7462765957446809 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:07,331] The parameter `criterion` in Trial#95 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,332] The parameter `max_features` in Trial#95 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,346] Trial 95 finished with value: 0.7463652482269504 and parameters: {'criterion': 'log_loss', 'max_features': 'log2', 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 8}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:07,346] The parameter `criterion` in Trial#96 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,346] The parameter `max_features` in Trial#96 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,363] Trial 96 finished with value: 0.7125 and parameters: {'criterion': 'log_loss', 'max_features': None, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:07,363] The parameter `criterion` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,365] The parameter `max_features` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,380] Trial 97 finished with value: 0.7170212765957447 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:07,380] The parameter `criterion` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,380] The parameter `max_features` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,397] Trial 98 finished with value: 0.7462765957446809 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 9}. Best is trial 37 with value: 0.7634751773049644.
# [W 2025-10-03 10:49:07,397] The parameter `criterion` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,397] The parameter `max_features` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,414] Trial 99 finished with value: 0.7382978723404254 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 37 with value: 0.7634751773049644.
#
# Best Hyperparameters for Decision Tree: (Using QMCSampler)
# {'criterion': 'entropy', 'max_features': 'sqrt', 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 1}

# %% [markdown]
# ### **4.3 Random Forest Hyperparameter Tuning**

# %%
random_forest = base_model_tuning('Random Forest', X_train, y_train, iterations=OPTIMIZATION_ITERATIONS, metric_compare=OPTIMIZATION_METRIC)
# Out:
# C:\Users\azhar\AppData\Local\Temp\ipykernel_23760\1802863948.py:41: ExperimentalWarning: QMCSampler is experimental (supported from v3.0.0). The interface can change in the future.
#   study = opt.create_study(study_name='Random Fine Tuning: Random Forest', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
# [I 2025-10-03 10:49:07,433] A new study created in memory with name: Random Fine Tuning: Random Forest
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-03 10:49:07,561] Trial 0 finished with value: 0.7676418439716313 and parameters: {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 15, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 8}. Best is trial 0 with value: 0.7676418439716313.
# [W 2025-10-03 10:49:07,563] The parameter `criterion` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,563] The parameter `max_features` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,661] Trial 1 finished with value: 0.7671985815602836 and parameters: {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 10, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 0 with value: 0.7676418439716313.
# [W 2025-10-03 10:49:07,662] The parameter `criterion` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,662] The parameter `max_features` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:07,824] Trial 2 finished with value: 0.7887411347517731 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'n_estimators': 55, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 2 with value: 0.7887411347517731.
# [W 2025-10-03 10:49:07,826] The parameter `criterion` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:07,827] The parameter `max_features` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:08,006] Trial 3 finished with value: 0.8055851063829786 and parameters: {'criterion': 'log_loss', 'max_features': 'sqrt', 'n_estimators': 78, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:08,008] The parameter `criterion` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:08,008] The parameter `max_features` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:08,107] Trial 4 finished with value: 0.7757978723404255 and parameters: {'criterion': 'log_loss', 'max_features': None, 'n_estimators': 32, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 8}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:08,108] The parameter `criterion` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:08,109] The parameter `max_features` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:08,207] Trial 5 finished with value: 0.7717198581560284 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 44, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 9}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:08,209] The parameter `criterion` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:08,210] The parameter `max_features` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:08,368] Trial 6 finished with value: 0.7969858156028369 and parameters: {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 89, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:08,370] The parameter `criterion` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:08,371] The parameter `max_features` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:08,500] Trial 7 finished with value: 0.8013297872340426 and parameters: {'criterion': 'log_loss', 'max_features': 'log2', 'n_estimators': 66, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 7}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:08,502] The parameter `criterion` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:08,503] The parameter `max_features` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:08,579] Trial 8 finished with value: 0.7677304964539007 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 21, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:08,581] The parameter `criterion` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:08,582] The parameter `max_features` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:08,667] Trial 9 finished with value: 0.7843971631205674 and parameters: {'criterion': 'log_loss', 'max_features': 'log2', 'n_estimators': 27, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:08,669] The parameter `criterion` in Trial#10 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:08,670] The parameter `max_features` in Trial#10 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:08,809] Trial 10 finished with value: 0.788563829787234 and parameters: {'criterion': 'entropy', 'max_features': None, 'n_estimators': 72, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:08,811] The parameter `criterion` in Trial#11 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:08,812] The parameter `max_features` in Trial#11 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:08,971] Trial 11 finished with value: 0.7929078014184398 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 95, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:08,973] The parameter `criterion` in Trial#12 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:08,974] The parameter `max_features` in Trial#12 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:09,081] Trial 12 finished with value: 0.784663120567376 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 49, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 7}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:09,084] The parameter `criterion` in Trial#13 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:09,084] The parameter `max_features` in Trial#13 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:09,180] Trial 13 finished with value: 0.7843971631205673 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 38, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:09,182] The parameter `criterion` in Trial#14 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:09,183] The parameter `max_features` in Trial#14 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:09,331] Trial 14 finished with value: 0.7970744680851064 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 83, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:09,333] The parameter `criterion` in Trial#15 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:09,333] The parameter `max_features` in Trial#15 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:09,461] Trial 15 finished with value: 0.7843085106382979 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 61, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 9}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:09,463] The parameter `criterion` in Trial#16 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:09,464] The parameter `max_features` in Trial#16 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:09,529] Trial 16 finished with value: 0.7886524822695036 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'n_estimators': 15, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:09,531] The parameter `criterion` in Trial#17 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:09,531] The parameter `max_features` in Trial#17 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:09,597] Trial 17 finished with value: 0.7929964539007093 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'n_estimators': 18, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 7}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:09,600] The parameter `criterion` in Trial#18 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:09,601] The parameter `max_features` in Trial#18 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:09,729] Trial 18 finished with value: 0.7759751773049646 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 64, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:09,731] The parameter `criterion` in Trial#19 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:09,732] The parameter `max_features` in Trial#19 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:09,892] Trial 19 finished with value: 0.7843971631205673 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 86, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:09,892] The parameter `criterion` in Trial#20 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:09,892] The parameter `max_features` in Trial#20 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:10,002] Trial 20 finished with value: 0.7886524822695036 and parameters: {'criterion': 'log_loss', 'max_features': 'sqrt', 'n_estimators': 41, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:10,003] The parameter `criterion` in Trial#21 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:10,005] The parameter `max_features` in Trial#21 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:10,123] Trial 21 finished with value: 0.7886524822695036 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 52, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:10,123] The parameter `criterion` in Trial#22 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:10,123] The parameter `max_features` in Trial#22 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:10,316] Trial 22 finished with value: 0.7843971631205673 and parameters: {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 98, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 8}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:10,316] The parameter `criterion` in Trial#23 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:10,316] The parameter `max_features` in Trial#23 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:10,468] Trial 23 finished with value: 0.7886524822695036 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 75, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:10,468] The parameter `criterion` in Trial#24 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:10,471] The parameter `max_features` in Trial#24 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:10,558] Trial 24 finished with value: 0.7673758865248226 and parameters: {'criterion': 'log_loss', 'max_features': None, 'n_estimators': 29, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:10,558] The parameter `criterion` in Trial#25 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:10,558] The parameter `max_features` in Trial#25 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:10,648] Trial 25 finished with value: 0.7844858156028369 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 24, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 9}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:10,649] The parameter `criterion` in Trial#26 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:10,649] The parameter `max_features` in Trial#26 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:10,800] Trial 26 finished with value: 0.7673758865248227 and parameters: {'criterion': 'log_loss', 'max_features': None, 'n_estimators': 69, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:10,802] The parameter `criterion` in Trial#27 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:10,803] The parameter `max_features` in Trial#27 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:10,972] Trial 27 finished with value: 0.7970744680851063 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 92, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:10,972] The parameter `criterion` in Trial#28 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:10,972] The parameter `max_features` in Trial#28 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:11,092] Trial 28 finished with value: 0.7928191489361702 and parameters: {'criterion': 'log_loss', 'max_features': 'log2', 'n_estimators': 46, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:11,095] The parameter `criterion` in Trial#29 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:11,095] The parameter `max_features` in Trial#29 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:11,192] Trial 29 finished with value: 0.7929078014184396 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 35, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:11,192] The parameter `criterion` in Trial#30 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:11,192] The parameter `max_features` in Trial#30 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:11,365] Trial 30 finished with value: 0.801418439716312 and parameters: {'criterion': 'log_loss', 'max_features': 'sqrt', 'n_estimators': 81, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 8}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:11,365] The parameter `criterion` in Trial#31 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:11,365] The parameter `max_features` in Trial#31 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:11,497] Trial 31 finished with value: 0.7843971631205674 and parameters: {'criterion': 'log_loss', 'max_features': 'sqrt', 'n_estimators': 58, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:11,499] The parameter `criterion` in Trial#32 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:11,500] The parameter `max_features` in Trial#32 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:11,567] Trial 32 finished with value: 0.763386524822695 and parameters: {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 12, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:11,567] The parameter `criterion` in Trial#33 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:11,567] The parameter `max_features` in Trial#33 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:11,636] Trial 33 finished with value: 0.7716312056737589 and parameters: {'criterion': 'entropy', 'max_features': None, 'n_estimators': 14, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 6}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:11,636] The parameter `criterion` in Trial#34 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:11,638] The parameter `max_features` in Trial#34 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:11,766] Trial 34 finished with value: 0.7803191489361703 and parameters: {'criterion': 'log_loss', 'max_features': 'sqrt', 'n_estimators': 59, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:11,766] The parameter `criterion` in Trial#35 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:11,766] The parameter `max_features` in Trial#35 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:11,928] Trial 35 finished with value: 0.7842198581560285 and parameters: {'criterion': 'gini', 'max_features': None, 'n_estimators': 82, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 8}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:11,930] The parameter `criterion` in Trial#36 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:11,930] The parameter `max_features` in Trial#36 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:12,028] Trial 36 finished with value: 0.7801418439716313 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 37, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:12,030] The parameter `criterion` in Trial#37 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:12,031] The parameter `max_features` in Trial#37 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:12,137] Trial 37 finished with value: 0.7969858156028369 and parameters: {'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 48, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:12,140] The parameter `criterion` in Trial#38 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:12,140] The parameter `max_features` in Trial#38 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:12,309] Trial 38 finished with value: 0.7843971631205674 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 93, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 10}. Best is trial 3 with value: 0.8055851063829786.
# [W 2025-10-03 10:49:12,311] The parameter `criterion` in Trial#39 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# ...
# [W 2025-10-03 10:49:18,560] The parameter `max_features` in Trial#87 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:18,761] Trial 87 finished with value: 0.7842198581560285 and parameters: {'criterion': 'gini', 'max_features': None, 'n_estimators': 77, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 9}. Best is trial 55 with value: 0.8098404255319149.
# [W 2025-10-03 10:49:18,761] The parameter `criterion` in Trial#88 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:18,761] The parameter `max_features` in Trial#88 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:18,873] Trial 88 finished with value: 0.788741134751773 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 32, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 55 with value: 0.8098404255319149.
# [W 2025-10-03 10:49:18,875] The parameter `criterion` in Trial#89 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:18,875] The parameter `max_features` in Trial#89 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:18,962] Trial 89 finished with value: 0.7590425531914894 and parameters: {'criterion': 'log_loss', 'max_features': None, 'n_estimators': 26, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 55 with value: 0.8098404255319149.
# [W 2025-10-03 10:49:18,962] The parameter `criterion` in Trial#90 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:18,962] The parameter `max_features` in Trial#90 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:19,135] Trial 90 finished with value: 0.7674645390070923 and parameters: {'criterion': 'gini', 'max_features': None, 'n_estimators': 71, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 6}. Best is trial 55 with value: 0.8098404255319149.
# [W 2025-10-03 10:49:19,136] The parameter `criterion` in Trial#91 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:19,137] The parameter `max_features` in Trial#91 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:19,349] Trial 91 finished with value: 0.7970744680851063 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'n_estimators': 94, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 55 with value: 0.8098404255319149.
# [W 2025-10-03 10:49:19,351] The parameter `criterion` in Trial#92 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:19,352] The parameter `max_features` in Trial#92 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:19,470] Trial 92 finished with value: 0.788563829787234 and parameters: {'criterion': 'log_loss', 'max_features': 'log2', 'n_estimators': 49, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 9}. Best is trial 55 with value: 0.8098404255319149.
# [W 2025-10-03 10:49:19,472] The parameter `criterion` in Trial#93 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:19,474] The parameter `max_features` in Trial#93 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:19,593] Trial 93 finished with value: 0.7844858156028369 and parameters: {'criterion': 'log_loss', 'max_features': 'sqrt', 'n_estimators': 37, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 10}. Best is trial 55 with value: 0.8098404255319149.
# [W 2025-10-03 10:49:19,596] The parameter `criterion` in Trial#94 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:19,596] The parameter `max_features` in Trial#94 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:19,766] Trial 94 finished with value: 0.8013297872340426 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 83, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 55 with value: 0.8098404255319149.
# [W 2025-10-03 10:49:19,766] The parameter `criterion` in Trial#95 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:19,766] The parameter `max_features` in Trial#95 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:19,906] Trial 95 finished with value: 0.7844858156028369 and parameters: {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 60, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 7}. Best is trial 55 with value: 0.8098404255319149.
# [W 2025-10-03 10:49:19,908] The parameter `criterion` in Trial#96 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:19,909] The parameter `max_features` in Trial#96 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:19,986] Trial 96 finished with value: 0.788563829787234 and parameters: {'criterion': 'entropy', 'max_features': 'log2', 'n_estimators': 14, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 55 with value: 0.8098404255319149.
# [W 2025-10-03 10:49:19,987] The parameter `criterion` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:19,988] The parameter `max_features` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:20,065] Trial 97 finished with value: 0.7462765957446809 and parameters: {'criterion': 'entropy', 'max_features': None, 'n_estimators': 13, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 55 with value: 0.8098404255319149.
# [W 2025-10-03 10:49:20,068] The parameter `criterion` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:20,069] The parameter `max_features` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:20,263] Trial 98 finished with value: 0.7928191489361702 and parameters: {'criterion': 'log_loss', 'max_features': 'log2', 'n_estimators': 59, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 9}. Best is trial 55 with value: 0.8098404255319149.
# [W 2025-10-03 10:49:20,263] The parameter `criterion` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:20,263] The parameter `max_features` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:20,426] Trial 99 finished with value: 0.7802304964539007 and parameters: {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 81, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 55 with value: 0.8098404255319149.
#
# Best Hyperparameters for Random Forest: (Using QMCSampler)
# {'criterion': 'log_loss', 'max_features': 'sqrt', 'n_estimators': 73, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 6}

# %% [markdown]
# ### **4.4 K-Nearest Neighbors Hyperparameter Tuning**

# %%
knn = base_model_tuning('K-Nearest Neighbors', X_train, y_train, iterations=OPTIMIZATION_ITERATIONS, metric_compare=OPTIMIZATION_METRIC)
# Out:
# C:\Users\azhar\AppData\Local\Temp\ipykernel_23760\1802863948.py:54: ExperimentalWarning: QMCSampler is experimental (supported from v3.0.0). The interface can change in the future.
#   study = opt.create_study(study_name='Random Fine Tuning: K-Nearest Neighbors', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
# [I 2025-10-03 10:49:20,446] A new study created in memory with name: Random Fine Tuning: K-Nearest Neighbors
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-03 10:49:20,501] Trial 0 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 31, 'p': 1}. Best is trial 0 with value: 0.7930851063829787.
# [W 2025-10-03 10:49:20,502] The parameter `algorithm` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:20,661] Trial 1 finished with value: 0.7549645390070923 and parameters: {'algorithm': 'brute', 'n_neighbors': 3, 'p': 1}. Best is trial 0 with value: 0.7930851063829787.
# [W 2025-10-03 10:49:20,663] The parameter `algorithm` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:20,710] Trial 2 finished with value: 0.7721631205673759 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 27, 'p': 1}. Best is trial 0 with value: 0.7930851063829787.
# [W 2025-10-03 10:49:20,711] The parameter `algorithm` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:20,758] Trial 3 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 39, 'p': 1}. Best is trial 0 with value: 0.7930851063829787.
# [W 2025-10-03 10:49:20,758] The parameter `algorithm` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:20,869] Trial 4 finished with value: 0.771985815602837 and parameters: {'algorithm': 'brute', 'n_neighbors': 15, 'p': 2}. Best is trial 0 with value: 0.7930851063829787.
# [W 2025-10-03 10:49:20,870] The parameter `algorithm` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:20,907] Trial 5 finished with value: 0.7805851063829786 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 21, 'p': 1}. Best is trial 0 with value: 0.7930851063829787.
# [W 2025-10-03 10:49:20,908] The parameter `algorithm` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:20,945] Trial 6 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 45, 'p': 2}. Best is trial 0 with value: 0.7930851063829787.
# [W 2025-10-03 10:49:20,945] The parameter `algorithm` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,054] Trial 7 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'brute', 'n_neighbors': 33, 'p': 1}. Best is trial 0 with value: 0.7930851063829787.
# [W 2025-10-03 10:49:21,055] The parameter `algorithm` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,195] Trial 8 finished with value: 0.7804964539007093 and parameters: {'algorithm': 'brute', 'n_neighbors': 9, 'p': 2}. Best is trial 0 with value: 0.7930851063829787.
# [W 2025-10-03 10:49:21,197] The parameter `algorithm` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,244] Trial 9 finished with value: 0.7678191489361701 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 11, 'p': 1}. Best is trial 0 with value: 0.7930851063829787.
# [W 2025-10-03 10:49:21,246] The parameter `algorithm` in Trial#10 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,354] Trial 10 finished with value: 0.7972517730496455 and parameters: {'algorithm': 'brute', 'n_neighbors': 35, 'p': 2}. Best is trial 10 with value: 0.7972517730496455.
# [W 2025-10-03 10:49:21,355] The parameter `algorithm` in Trial#11 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,392] Trial 11 finished with value: 0.788918439716312 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 47, 'p': 1}. Best is trial 10 with value: 0.7972517730496455.
# [W 2025-10-03 10:49:21,392] The parameter `algorithm` in Trial#12 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,429] Trial 12 finished with value: 0.7806737588652481 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 23, 'p': 2}. Best is trial 10 with value: 0.7972517730496455.
# [W 2025-10-03 10:49:21,429] The parameter `algorithm` in Trial#13 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,538] Trial 13 finished with value: 0.7931737588652481 and parameters: {'algorithm': 'brute', 'n_neighbors': 17, 'p': 1}. Best is trial 10 with value: 0.7972517730496455.
# [W 2025-10-03 10:49:21,538] The parameter `algorithm` in Trial#14 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,575] Trial 14 finished with value: 0.7929964539007093 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 41, 'p': 2}. Best is trial 10 with value: 0.7972517730496455.
# [W 2025-10-03 10:49:21,575] The parameter `algorithm` in Trial#15 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,613] Trial 15 finished with value: 0.7805851063829787 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 29, 'p': 1}. Best is trial 10 with value: 0.7972517730496455.
# [W 2025-10-03 10:49:21,613] The parameter `algorithm` in Trial#16 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,650] Trial 16 finished with value: 0.7886524822695036 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 2}. Best is trial 10 with value: 0.7972517730496455.
# [W 2025-10-03 10:49:21,650] The parameter `algorithm` in Trial#17 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,677] Trial 17 finished with value: 0.7971631205673757 and parameters: {'algorithm': 'brute', 'n_neighbors': 7, 'p': 1}. Best is trial 10 with value: 0.7972517730496455.
# [W 2025-10-03 10:49:21,677] The parameter `algorithm` in Trial#18 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,713] Trial 18 finished with value: 0.7973404255319149 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 31, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:21,714] The parameter `algorithm` in Trial#19 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,750] Trial 19 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 43, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:21,751] The parameter `algorithm` in Trial#20 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,788] Trial 20 finished with value: 0.7847517730496454 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 19, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:21,788] The parameter `algorithm` in Trial#21 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:21,917] Trial 21 finished with value: 0.7721631205673759 and parameters: {'algorithm': 'brute', 'n_neighbors': 25, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:21,917] The parameter `algorithm` in Trial#22 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,015] Trial 22 finished with value: 0.788918439716312 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 49, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,021] The parameter `algorithm` in Trial#23 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,054] Trial 23 finished with value: 0.7931737588652482 and parameters: {'algorithm': 'brute', 'n_neighbors': 37, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,056] The parameter `algorithm` in Trial#24 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,093] Trial 24 finished with value: 0.7890070921985816 and parameters: {'algorithm': 'brute', 'n_neighbors': 13, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,095] The parameter `algorithm` in Trial#25 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,156] Trial 25 finished with value: 0.788918439716312 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 10, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,159] The parameter `algorithm` in Trial#26 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,237] Trial 26 finished with value: 0.788918439716312 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 34, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,239] The parameter `algorithm` in Trial#27 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,275] Trial 27 finished with value: 0.7888297872340425 and parameters: {'algorithm': 'brute', 'n_neighbors': 46, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,279] The parameter `algorithm` in Trial#28 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,481] Trial 28 finished with value: 0.7765070921985815 and parameters: {'algorithm': 'brute', 'n_neighbors': 22, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,481] The parameter `algorithm` in Trial#29 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,511] Trial 29 finished with value: 0.7973404255319149 and parameters: {'algorithm': 'brute', 'n_neighbors': 16, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,511] The parameter `algorithm` in Trial#30 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,540] Trial 30 finished with value: 0.7972517730496455 and parameters: {'algorithm': 'brute', 'n_neighbors': 40, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,541] The parameter `algorithm` in Trial#31 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,589] Trial 31 finished with value: 0.7805851063829787 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 28, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,591] The parameter `algorithm` in Trial#32 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,639] Trial 32 finished with value: 0.7677304964539007 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 4, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,641] The parameter `algorithm` in Trial#33 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,689] Trial 33 finished with value: 0.7971631205673757 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,691] The parameter `algorithm` in Trial#34 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,738] Trial 34 finished with value: 0.7805851063829787 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 29, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,739] The parameter `algorithm` in Trial#35 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,785] Trial 35 finished with value: 0.7888297872340425 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 41, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,788] The parameter `algorithm` in Trial#36 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,814] Trial 36 finished with value: 0.7888297872340425 and parameters: {'algorithm': 'brute', 'n_neighbors': 17, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,814] The parameter `algorithm` in Trial#37 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,842] Trial 37 finished with value: 0.7764184397163121 and parameters: {'algorithm': 'brute', 'n_neighbors': 23, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,842] The parameter `algorithm` in Trial#38 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,873] Trial 38 finished with value: 0.788918439716312 and parameters: {'algorithm': 'brute', 'n_neighbors': 47, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,874] The parameter `algorithm` in Trial#39 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,902] Trial 39 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'brute', 'n_neighbors': 35, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,905] The parameter `algorithm` in Trial#40 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,952] Trial 40 finished with value: 0.7762411347517731 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 11, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,952] The parameter `algorithm` in Trial#41 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:22,980] Trial 41 finished with value: 0.7804078014184397 and parameters: {'algorithm': 'brute', 'n_neighbors': 14, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:22,981] The parameter `algorithm` in Trial#42 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,041] Trial 42 finished with value: 0.7929964539007093 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 38, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:23,043] The parameter `algorithm` in Trial#43 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,070] Trial 43 finished with value: 0.7888297872340425 and parameters: {'algorithm': 'brute', 'n_neighbors': 50, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:23,070] The parameter `algorithm` in Trial#44 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,120] Trial 44 finished with value: 0.7805851063829786 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 26, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:23,120] The parameter `algorithm` in Trial#45 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,149] Trial 45 finished with value: 0.7890070921985816 and parameters: {'algorithm': 'brute', 'n_neighbors': 20, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:23,150] The parameter `algorithm` in Trial#46 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,201] Trial 46 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 44, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:23,203] The parameter `algorithm` in Trial#47 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,250] Trial 47 finished with value: 0.788918439716312 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 32, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:23,252] The parameter `algorithm` in Trial#48 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,299] Trial 48 finished with value: 0.788918439716312 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 8, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:23,299] The parameter `algorithm` in Trial#49 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,349] Trial 49 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 6, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:23,351] The parameter `algorithm` in Trial#50 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,378] Trial 50 finished with value: 0.7805851063829787 and parameters: {'algorithm': 'brute', 'n_neighbors': 30, 'p': 2}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:23,380] The parameter `algorithm` in Trial#51 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,407] Trial 51 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'brute', 'n_neighbors': 42, 'p': 1}. Best is trial 18 with value: 0.7973404255319149.
# [W 2025-10-03 10:49:23,409] The parameter `algorithm` in Trial#52 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,457] Trial 52 finished with value: 0.801595744680851 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 18, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,459] The parameter `algorithm` in Trial#53 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,507] Trial 53 finished with value: 0.7805851063829786 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 24, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,507] The parameter `algorithm` in Trial#54 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,556] Trial 54 finished with value: 0.788918439716312 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 48, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,556] The parameter `algorithm` in Trial#55 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,584] Trial 55 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'brute', 'n_neighbors': 36, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,585] The parameter `algorithm` in Trial#56 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,632] Trial 56 finished with value: 0.771985815602837 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 12, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,633] The parameter `algorithm` in Trial#57 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,669] Trial 57 finished with value: 0.784663120567376 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 9, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,669] The parameter `algorithm` in Trial#58 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,696] Trial 58 finished with value: 0.7888297872340425 and parameters: {'algorithm': 'brute', 'n_neighbors': 33, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,697] The parameter `algorithm` in Trial#59 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,733] Trial 59 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 45, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,733] The parameter `algorithm` in Trial#60 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,771] Trial 60 finished with value: 0.7804964539007093 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 21, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,772] The parameter `algorithm` in Trial#61 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,808] Trial 61 finished with value: 0.7845744680851063 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 15, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,809] The parameter `algorithm` in Trial#62 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,845] Trial 62 finished with value: 0.7929964539007093 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 39, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,846] The parameter `algorithm` in Trial#63 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,883] Trial 63 finished with value: 0.7721631205673759 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 27, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,884] The parameter `algorithm` in Trial#64 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,910] Trial 64 finished with value: 0.7550531914893617 and parameters: {'algorithm': 'brute', 'n_neighbors': 3, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,911] The parameter `algorithm` in Trial#65 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,948] Trial 65 finished with value: 0.7549645390070922 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 4, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,949] The parameter `algorithm` in Trial#66 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:23,985] Trial 66 finished with value: 0.7847517730496454 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 28, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:23,987] The parameter `algorithm` in Trial#67 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,022] Trial 67 finished with value: 0.7972517730496455 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 40, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,024] The parameter `algorithm` in Trial#68 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,059] Trial 68 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 16, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,061] The parameter `algorithm` in Trial#69 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,087] Trial 69 finished with value: 0.7805851063829786 and parameters: {'algorithm': 'brute', 'n_neighbors': 22, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,089] The parameter `algorithm` in Trial#70 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,115] Trial 70 finished with value: 0.7888297872340425 and parameters: {'algorithm': 'brute', 'n_neighbors': 46, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,116] The parameter `algorithm` in Trial#71 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,141] Trial 71 finished with value: 0.788918439716312 and parameters: {'algorithm': 'brute', 'n_neighbors': 34, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# ...
# [I 2025-10-03 10:49:24,354] Trial 76 finished with value: 0.7763297872340426 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 25, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,356] The parameter `algorithm` in Trial#77 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,383] Trial 77 finished with value: 0.788918439716312 and parameters: {'algorithm': 'brute', 'n_neighbors': 19, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,384] The parameter `algorithm` in Trial#78 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,413] Trial 78 finished with value: 0.7972517730496455 and parameters: {'algorithm': 'brute', 'n_neighbors': 43, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,414] The parameter `algorithm` in Trial#79 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,440] Trial 79 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'brute', 'n_neighbors': 31, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,441] The parameter `algorithm` in Trial#80 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,488] Trial 80 finished with value: 0.7843971631205674 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 7, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,490] The parameter `algorithm` in Trial#81 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,517] Trial 81 finished with value: 0.801595744680851 and parameters: {'algorithm': 'brute', 'n_neighbors': 8, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,518] The parameter `algorithm` in Trial#82 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,564] Trial 82 finished with value: 0.7888297872340425 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 32, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,565] The parameter `algorithm` in Trial#83 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,601] Trial 83 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 44, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,604] The parameter `algorithm` in Trial#84 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,628] Trial 84 finished with value: 0.7804964539007093 and parameters: {'algorithm': 'brute', 'n_neighbors': 20, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,630] The parameter `algorithm` in Trial#85 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,666] Trial 85 finished with value: 0.7763297872340426 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 26, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,667] The parameter `algorithm` in Trial#86 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,703] Trial 86 finished with value: 0.7930851063829787 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 50, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,704] The parameter `algorithm` in Trial#87 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,739] Trial 87 finished with value: 0.7972517730496455 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 38, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,740] The parameter `algorithm` in Trial#88 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,776] Trial 88 finished with value: 0.7846631205673759 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 14, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,777] The parameter `algorithm` in Trial#89 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,803] Trial 89 finished with value: 0.7678191489361701 and parameters: {'algorithm': 'brute', 'n_neighbors': 11, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,805] The parameter `algorithm` in Trial#90 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,840] Trial 90 finished with value: 0.7972517730496455 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 35, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,841] The parameter `algorithm` in Trial#91 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,877] Trial 91 finished with value: 0.788918439716312 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 47, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,878] The parameter `algorithm` in Trial#92 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,903] Trial 92 finished with value: 0.7806737588652481 and parameters: {'algorithm': 'brute', 'n_neighbors': 23, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,904] The parameter `algorithm` in Trial#93 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,940] Trial 93 finished with value: 0.7931737588652481 and parameters: {'algorithm': 'kd_tree', 'n_neighbors': 17, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,941] The parameter `algorithm` in Trial#94 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:24,977] Trial 94 finished with value: 0.7929964539007093 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 41, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:24,978] The parameter `algorithm` in Trial#95 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,003] Trial 95 finished with value: 0.7805851063829787 and parameters: {'algorithm': 'brute', 'n_neighbors': 29, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:25,004] The parameter `algorithm` in Trial#96 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,020] Trial 96 finished with value: 0.7886524822695036 and parameters: {'algorithm': 'brute', 'n_neighbors': 5, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:25,022] The parameter `algorithm` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,047] Trial 97 finished with value: 0.7549645390070922 and parameters: {'algorithm': 'brute', 'n_neighbors': 4, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:25,048] The parameter `algorithm` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,084] Trial 98 finished with value: 0.7847517730496454 and parameters: {'algorithm': 'ball_tree', 'n_neighbors': 28, 'p': 2}. Best is trial 52 with value: 0.801595744680851.
# [W 2025-10-03 10:49:25,085] The parameter `algorithm` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,110] Trial 99 finished with value: 0.7972517730496455 and parameters: {'algorithm': 'brute', 'n_neighbors': 40, 'p': 1}. Best is trial 52 with value: 0.801595744680851.
#
# Best Hyperparameters for K-Nearest Neighbors: (Using QMCSampler)
# {'algorithm': 'kd_tree', 'n_neighbors': 18, 'p': 2}

# %% [markdown]
# ### **4.5 Support Vector Machine Hyperparameter Tuning**

# %%
svm = base_model_tuning('Support Vector Machine', X_train, y_train, iterations=OPTIMIZATION_ITERATIONS, metric_compare=OPTIMIZATION_METRIC)
# Out:
# C:\Users\azhar\AppData\Local\Temp\ipykernel_23760\1802863948.py:67: ExperimentalWarning: QMCSampler is experimental (supported from v3.0.0). The interface can change in the future.
#   study = opt.create_study(study_name='Random Fine Tuning: Support Vector Machine', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
# [I 2025-10-03 10:49:25,128] A new study created in memory with name: Random Fine Tuning: Support Vector Machine
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-03 10:49:25,161] Trial 0 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.0015751320499779737}. Best is trial 0 with value: 0.52322695035461.
# [W 2025-10-03 10:49:25,162] The parameter `kernel` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,190] Trial 1 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.00010000000000000009}. Best is trial 0 with value: 0.52322695035461.
# [W 2025-10-03 10:49:25,193] The parameter `kernel` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,221] Trial 2 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0010000000000000002}. Best is trial 0 with value: 0.52322695035461.
# [W 2025-10-03 10:49:25,223] The parameter `kernel` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,239] Trial 3 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.003162277660168382}. Best is trial 0 with value: 0.52322695035461.
# [W 2025-10-03 10:49:25,242] The parameter `kernel` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,256] Trial 4 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0003162277660168384}. Best is trial 0 with value: 0.52322695035461.
# [W 2025-10-03 10:49:25,257] The parameter `kernel` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,273] Trial 5 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.0005623413251903495}. Best is trial 0 with value: 0.52322695035461.
# [W 2025-10-03 10:49:25,274] The parameter `kernel` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,289] Trial 6 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.005623413251903492}. Best is trial 0 with value: 0.52322695035461.
# [W 2025-10-03 10:49:25,291] The parameter `kernel` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:25,292] The parameter `degree` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,306] Trial 7 finished with value: 0.7 and parameters: {'kernel': 'poly', 'C': 0.0017782794100389236, 'degree': 5}. Best is trial 7 with value: 0.7.
# [W 2025-10-03 10:49:25,308] The parameter `kernel` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:25,310] The parameter `degree` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,324] Trial 8 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.00017782794100389232, 'degree': 2}. Best is trial 7 with value: 0.7.
# [W 2025-10-03 10:49:25,325] The parameter `kernel` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,340] Trial 9 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.00023713737056616573}. Best is trial 7 with value: 0.7.
# [W 2025-10-03 10:49:25,342] The parameter `kernel` in Trial#10 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,368] Trial 10 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.002371373705661656}. Best is trial 7 with value: 0.7.
# [W 2025-10-03 10:49:25,370] The parameter `kernel` in Trial#11 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:25,371] The parameter `degree` in Trial#11 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,385] Trial 11 finished with value: 0.7467198581560284 and parameters: {'kernel': 'poly', 'C': 0.007498942093324564, 'degree': 3}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,387] The parameter `kernel` in Trial#12 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,402] Trial 12 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.0007498942093324562}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,402] The parameter `kernel` in Trial#13 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,429] Trial 13 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.00042169650342858235}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,430] The parameter `kernel` in Trial#14 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:25,431] The parameter `degree` in Trial#14 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,446] Trial 14 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.004216965034285825, 'degree': 2}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,447] The parameter `kernel` in Trial#15 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,462] Trial 15 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0013335214321633251}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,463] The parameter `kernel` in Trial#16 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:25,465] The parameter `degree` in Trial#16 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,479] Trial 16 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.0001333521432163326, 'degree': 2}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,481] The parameter `kernel` in Trial#17 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:25,482] The parameter `degree` in Trial#17 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,496] Trial 17 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.00015399265260594933, 'degree': 3}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,497] The parameter `kernel` in Trial#18 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,513] Trial 18 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.0015399265260594922}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,514] The parameter `kernel` in Trial#19 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,540] Trial 19 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.004869675251658635}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,542] The parameter `kernel` in Trial#20 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:25,543] The parameter `degree` in Trial#20 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,568] Trial 20 finished with value: 0.5568262411347518 and parameters: {'kernel': 'poly', 'C': 0.00048696752516586337, 'degree': 5}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,569] The parameter `kernel` in Trial#21 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:25,570] The parameter `degree` in Trial#21 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,585] Trial 21 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.000865964323360066, 'degree': 4}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,587] The parameter `kernel` in Trial#22 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,601] Trial 22 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.008659643233600654}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,602] The parameter `kernel` in Trial#23 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:25,604] The parameter `degree` in Trial#23 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,618] Trial 23 finished with value: 0.6914893617021277 and parameters: {'kernel': 'poly', 'C': 0.0027384196342643626, 'degree': 4}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,619] The parameter `kernel` in Trial#24 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,636] Trial 24 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0002738419634264362}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,637] The parameter `kernel` in Trial#25 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,653] Trial 25 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.0002053525026457149}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,654] The parameter `kernel` in Trial#26 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,670] Trial 26 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0020535250264571477}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,671] The parameter `kernel` in Trial#27 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,686] Trial 27 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.0064938163157621165}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,687] The parameter `kernel` in Trial#28 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,713] Trial 28 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0006493816315762115}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,714] The parameter `kernel` in Trial#29 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,730] Trial 29 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.000365174127254838}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,731] The parameter `kernel` in Trial#30 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,746] Trial 30 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.0036517412725483775}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,747] The parameter `kernel` in Trial#31 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,764] Trial 31 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.0011547819846894588}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,765] The parameter `kernel` in Trial#32 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,791] Trial 32 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.00011547819846894585}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,793] The parameter `kernel` in Trial#33 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,808] Trial 33 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.00012409377607517218}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,810] The parameter `kernel` in Trial#34 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,835] Trial 34 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0012409377607517208}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,837] The parameter `kernel` in Trial#35 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,864] Trial 35 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.003924189758484535}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,865] The parameter `kernel` in Trial#36 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,892] Trial 36 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0003924189758484538}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,893] The parameter `kernel` in Trial#37 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,908] Trial 37 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0006978305848598669}. Best is trial 11 with value: 0.7467198581560284.
# [W 2025-10-03 10:49:25,908] The parameter `kernel` in Trial#38 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:25,910] The parameter `degree` in Trial#38 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,925] Trial 38 finished with value: 0.7634751773049645 and parameters: {'kernel': 'poly', 'C': 0.006978305848598664, 'degree': 5}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:25,927] The parameter `kernel` in Trial#39 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,941] Trial 39 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.002206734069084591}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:25,942] The parameter `kernel` in Trial#40 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:25,943] The parameter `degree` in Trial#40 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,968] Trial 40 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.00022067340690845924, 'degree': 5}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:25,969] The parameter `kernel` in Trial#41 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:25,971] The parameter `degree` in Trial#41 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:25,985] Trial 41 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.0002942727176209287, 'degree': 3}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:25,987] The parameter `kernel` in Trial#42 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,002] Trial 42 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.002942727176209285}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,003] The parameter `kernel` in Trial#43 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,018] Trial 43 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.009305720409296997}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,019] The parameter `kernel` in Trial#44 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,035] Trial 44 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.0009305720409296995}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,037] The parameter `kernel` in Trial#45 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:26,038] The parameter `degree` in Trial#45 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,052] Trial 45 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.0005232991146814953, 'degree': 2}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,053] The parameter `kernel` in Trial#46 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:26,054] The parameter `degree` in Trial#46 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,069] Trial 46 finished with value: 0.5568262411347518 and parameters: {'kernel': 'poly', 'C': 0.005232991146814949, 'degree': 2}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,070] The parameter `kernel` in Trial#47 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,085] Trial 47 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.0016548170999431827}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,086] The parameter `kernel` in Trial#48 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,101] Trial 48 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.00016548170999431823}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,102] The parameter `kernel` in Trial#49 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,127] Trial 49 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.00014330125702369644}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,128] The parameter `kernel` in Trial#50 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,144] Trial 50 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0014330125702369636}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,146] The parameter `kernel` in Trial#51 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:26,147] The parameter `degree` in Trial#51 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,161] Trial 51 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.0045315836376008225, 'degree': 2}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,162] The parameter `kernel` in Trial#52 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:26,164] The parameter `degree` in Trial#52 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,178] Trial 52 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.00045315836376008217, 'degree': 2}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,180] The parameter `kernel` in Trial#53 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:26,181] The parameter `degree` in Trial#53 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,195] Trial 53 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.0008058421877614828, 'degree': 2}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,196] The parameter `kernel` in Trial#54 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:26,198] The parameter `degree` in Trial#54 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,212] Trial 54 finished with value: 0.7634751773049645 and parameters: {'kernel': 'poly', 'C': 0.008058421877614822, 'degree': 5}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,214] The parameter `kernel` in Trial#55 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:26,215] The parameter `degree` in Trial#55 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,229] Trial 55 finished with value: 0.6703900709219859 and parameters: {'kernel': 'poly', 'C': 0.0025482967479793484, 'degree': 4}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,231] The parameter `kernel` in Trial#56 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,246] Trial 56 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0002548296747979348}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,248] The parameter `kernel` in Trial#57 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,262] Trial 57 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.00019109529749704405}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,263] The parameter `kernel` in Trial#58 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# ...
# [I 2025-10-03 10:49:26,721] Trial 80 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.00014855080171727767, 'degree': 5}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,723] The parameter `kernel` in Trial#81 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,766] Trial 81 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.00017154378963428796}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,768] The parameter `kernel` in Trial#82 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,796] Trial 82 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0017154378963428801}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,797] The parameter `kernel` in Trial#83 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,812] Trial 83 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.005424690937011328}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,814] The parameter `kernel` in Trial#84 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:26,815] The parameter `degree` in Trial#84 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,828] Trial 84 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.0005424690937011332, 'degree': 2}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,829] The parameter `kernel` in Trial#85 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,845] Trial 85 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.0009646616199111995}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,845] The parameter `kernel` in Trial#86 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,861] Trial 86 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.009646616199111998}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,863] The parameter `kernel` in Trial#87 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,879] Trial 87 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0030505278902670284}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,879] The parameter `kernel` in Trial#88 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,895] Trial 88 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.00030505278902670253}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,896] The parameter `kernel` in Trial#89 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,911] Trial 89 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0002287573200318398}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,912] The parameter `kernel` in Trial#90 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:26,913] The parameter `degree` in Trial#90 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,928] Trial 90 finished with value: 0.6534574468085107 and parameters: {'kernel': 'poly', 'C': 0.0022875732003183966, 'degree': 4}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,929] The parameter `kernel` in Trial#91 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,945] Trial 91 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.007233941627366754}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,946] The parameter `kernel` in Trial#92 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,961] Trial 92 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0007233941627366753}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,963] The parameter `kernel` in Trial#93 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:26,963] The parameter `degree` in Trial#93 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:26,978] Trial 93 finished with value: 0.5358156028368793 and parameters: {'kernel': 'poly', 'C': 0.0004067944321083049, 'degree': 5}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:26,979] The parameter `kernel` in Trial#94 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:27,005] Trial 94 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.0040679443210830495}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:27,006] The parameter `kernel` in Trial#95 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:27,008] The parameter `degree` in Trial#95 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:27,023] Trial 95 finished with value: 0.5821808510638299 and parameters: {'kernel': 'poly', 'C': 0.0012863969449369757, 'degree': 4}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:27,024] The parameter `kernel` in Trial#96 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:27,025] The parameter `degree` in Trial#96 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:27,040] Trial 96 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.00012863969449369766, 'degree': 4}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:27,041] The parameter `kernel` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:27,066] Trial 97 finished with value: 0.52322695035461 and parameters: {'kernel': 'sigmoid', 'C': 0.00011970850304957301}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:27,068] The parameter `kernel` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:27,069] The parameter `degree` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:27,084] Trial 98 finished with value: 0.52322695035461 and parameters: {'kernel': 'poly', 'C': 0.0011970850304957315, 'degree': 2}. Best is trial 38 with value: 0.7634751773049645.
# [W 2025-10-03 10:49:27,086] The parameter `kernel` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:27,100] Trial 99 finished with value: 0.52322695035461 and parameters: {'kernel': 'rbf', 'C': 0.00378551524925863}. Best is trial 38 with value: 0.7634751773049645.
#
# Best Hyperparameters for Support Vector Machine: (Using QMCSampler)
# {'kernel': 'poly', 'C': 0.006978305848598664, 'degree': 5}

# %% [markdown]
# ### **4.6 Adaptive Boosting Hyperparameter Tuning**

# %%
adaboost = base_model_tuning('AdaBoost', X_train, y_train, iterations=OPTIMIZATION_ITERATIONS, metric_compare=OPTIMIZATION_METRIC)
# Out:
# C:\Users\azhar\AppData\Local\Temp\ipykernel_23760\1802863948.py:79: ExperimentalWarning: QMCSampler is experimental (supported from v3.0.0). The interface can change in the future.
#   study = opt.create_study(study_name='Random Fine Tuning: AdaBoost', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
# [I 2025-10-03 10:49:27,116] A new study created in memory with name: Random Fine Tuning: AdaBoost
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-03 10:49:27,222] Trial 0 finished with value: 0.8139184397163121 and parameters: {'n_estimators': 44, 'learning_rate': 0.711447600934342}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:27,259] Trial 1 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 10, 'learning_rate': 0.0010000000000000002}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:27,348] Trial 2 finished with value: 0.738031914893617 and parameters: {'n_estimators': 55, 'learning_rate': 0.0316227766016838}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:27,470] Trial 3 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 78, 'learning_rate': 0.005623413251903492}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:27,527] Trial 4 finished with value: 0.775886524822695 and parameters: {'n_estimators': 32, 'learning_rate': 0.1778279410038923}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:27,606] Trial 5 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 44, 'learning_rate': 0.013335214321633242}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:27,767] Trial 6 finished with value: 0.8097517730496454 and parameters: {'n_estimators': 89, 'learning_rate': 0.4216965034285823}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:27,888] Trial 7 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 66, 'learning_rate': 0.002371373705661656}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:27,944] Trial 8 finished with value: 0.738031914893617 and parameters: {'n_estimators': 21, 'learning_rate': 0.07498942093324559}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:28,013] Trial 9 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 27, 'learning_rate': 0.008659643233600654}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:28,121] Trial 10 finished with value: 0.7886524822695036 and parameters: {'n_estimators': 72, 'learning_rate': 0.27384196342643613}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:28,263] Trial 11 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 95, 'learning_rate': 0.0015399265260594922}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:28,340] Trial 12 finished with value: 0.7422872340425531 and parameters: {'n_estimators': 49, 'learning_rate': 0.04869675251658632}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:28,408] Trial 13 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 38, 'learning_rate': 0.0036517412725483775}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:28,546] Trial 14 finished with value: 0.7718085106382979 and parameters: {'n_estimators': 83, 'learning_rate': 0.11547819846894583}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:28,666] Trial 15 finished with value: 0.7337765957446808 and parameters: {'n_estimators': 61, 'learning_rate': 0.020535250264571463}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:28,702] Trial 16 finished with value: 0.7507978723404255 and parameters: {'n_estimators': 15, 'learning_rate': 0.6493816315762113}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:28,739] Trial 17 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 18, 'learning_rate': 0.025482967479793468}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:28,849] Trial 18 finished with value: 0.7927304964539006 and parameters: {'n_estimators': 64, 'learning_rate': 0.8058421877614819}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:28,990] Trial 19 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 86, 'learning_rate': 0.004531583637600819}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:29,067] Trial 20 finished with value: 0.7800531914893617 and parameters: {'n_estimators': 41, 'learning_rate': 0.14330125702369628}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:29,177] Trial 21 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 52, 'learning_rate': 0.001910952974970441}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:29,327] Trial 22 finished with value: 0.7715425531914893 and parameters: {'n_estimators': 98, 'learning_rate': 0.060429639023813285}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:29,456] Trial 23 finished with value: 0.7338652482269504 and parameters: {'n_estimators': 75, 'learning_rate': 0.010746078283213176}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:29,512] Trial 24 finished with value: 0.7716312056737589 and parameters: {'n_estimators': 29, 'learning_rate': 0.33982083289425596}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:29,561] Trial 25 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 24, 'learning_rate': 0.0029427271762092824}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:29,669] Trial 26 finished with value: 0.7716312056737589 and parameters: {'n_estimators': 69, 'learning_rate': 0.0930572040929699}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:29,819] Trial 27 finished with value: 0.738031914893617 and parameters: {'n_estimators': 92, 'learning_rate': 0.016548170999431816}. Best is trial 0 with value: 0.8139184397163121.
# [I 2025-10-03 10:49:29,897] Trial 28 finished with value: 0.814095744680851 and parameters: {'n_estimators': 46, 'learning_rate': 0.5232991146814947}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:29,966] Trial 29 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 35, 'learning_rate': 0.006978305848598664}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:30,085] Trial 30 finished with value: 0.7970744680851064 and parameters: {'n_estimators': 81, 'learning_rate': 0.220673406908459}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:30,188] Trial 31 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 58, 'learning_rate': 0.0012409377607517198}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:30,223] Trial 32 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 12, 'learning_rate': 0.039241897584845364}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:30,262] Trial 33 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 14, 'learning_rate': 0.006264335366568854}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:30,372] Trial 34 finished with value: 0.7716312056737589 and parameters: {'n_estimators': 59, 'learning_rate': 0.1980956778550338}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:30,494] Trial 35 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 82, 'learning_rate': 0.0011139738599948022}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:30,572] Trial 36 finished with value: 0.7337765957446808 and parameters: {'n_estimators': 37, 'learning_rate': 0.03522694651473102}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:30,662] Trial 37 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 48, 'learning_rate': 0.0026416483203860917}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:30,802] Trial 38 finished with value: 0.7800531914893616 and parameters: {'n_estimators': 93, 'learning_rate': 0.08353625469578259}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:30,914] Trial 39 finished with value: 0.750531914893617 and parameters: {'n_estimators': 71, 'learning_rate': 0.014855080171727746}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:30,961] Trial 40 finished with value: 0.7843971631205673 and parameters: {'n_estimators': 25, 'learning_rate': 0.469758881670649}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:31,019] Trial 41 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 31, 'learning_rate': 0.0017154378963428786}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:31,138] Trial 42 finished with value: 0.7716312056737589 and parameters: {'n_estimators': 76, 'learning_rate': 0.05424690937011326}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:31,289] Trial 43 finished with value: 0.7338652482269504 and parameters: {'n_estimators': 99, 'learning_rate': 0.00964661619911199}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:31,377] Trial 44 finished with value: 0.7928191489361702 and parameters: {'n_estimators': 54, 'learning_rate': 0.3050527890267024}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:31,446] Trial 45 finished with value: 0.750531914893617 and parameters: {'n_estimators': 42, 'learning_rate': 0.02287573200318396}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:31,575] Trial 46 finished with value: 0.7969858156028369 and parameters: {'n_estimators': 88, 'learning_rate': 0.7233941627366745}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:31,685] Trial 47 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 65, 'learning_rate': 0.004067944321083046}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:31,731] Trial 48 finished with value: 0.7465425531914893 and parameters: {'n_estimators': 19, 'learning_rate': 0.12863969449369742}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:31,770] Trial 49 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 17, 'learning_rate': 0.005048065716667474}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:31,868] Trial 50 finished with value: 0.7632978723404256 and parameters: {'n_estimators': 62, 'learning_rate': 0.1596338544287943}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:32,000] Trial 51 finished with value: 0.7507978723404255 and parameters: {'n_estimators': 85, 'learning_rate': 0.02838735964758755}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:32,076] Trial 52 finished with value: 0.8097517730496454 and parameters: {'n_estimators': 39, 'learning_rate': 0.8976871324473146}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:32,156] Trial 53 finished with value: 0.7338652482269504 and parameters: {'n_estimators': 51, 'learning_rate': 0.011970850304957308}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:32,297] Trial 54 finished with value: 0.8096631205673759 and parameters: {'n_estimators': 96, 'learning_rate': 0.3785515249258632}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:32,418] Trial 55 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 73, 'learning_rate': 0.002128751661796374}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:32,475] Trial 56 finished with value: 0.738031914893617 and parameters: {'n_estimators': 28, 'learning_rate': 0.06731703824144986}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:32,524] Trial 57 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 22, 'learning_rate': 0.018434229924091106}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:32,631] Trial 58 finished with value: 0.8095744680851065 and parameters: {'n_estimators': 68, 'learning_rate': 0.5829415347136077}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:32,772] Trial 59 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 91, 'learning_rate': 0.003278121151393461}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:32,849] Trial 60 finished with value: 0.7674645390070922 and parameters: {'n_estimators': 45, 'learning_rate': 0.10366329284376985}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:32,909] Trial 61 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 34, 'learning_rate': 0.0013823722273579005}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:33,051] Trial 62 finished with value: 0.7548758865248226 and parameters: {'n_estimators': 79, 'learning_rate': 0.0437144481261109}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:33,139] Trial 63 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 56, 'learning_rate': 0.007773650302387762}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:33,176] Trial 64 finished with value: 0.7464539007092199 and parameters: {'n_estimators': 11, 'learning_rate': 0.24582440689201987}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:33,213] Trial 65 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 12, 'learning_rate': 0.01567878843826971}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:33,311] Trial 66 finished with value: 0.8138297872340425 and parameters: {'n_estimators': 57, 'learning_rate': 0.4958068241684657}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:33,432] Trial 67 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 80, 'learning_rate': 0.0027881266654131345}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:33,499] Trial 68 finished with value: 0.7506205673758866 and parameters: {'n_estimators': 34, 'learning_rate': 0.08816830667755711}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:33,579] Trial 69 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 46, 'learning_rate': 0.0011757432659207114}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:33,729] Trial 70 finished with value: 0.7548758865248226 and parameters: {'n_estimators': 91, 'learning_rate': 0.037180266639144754}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:33,858] Trial 71 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 69, 'learning_rate': 0.006611690262414818}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:33,915] Trial 72 finished with value: 0.7588652482269505 and parameters: {'n_estimators': 23, 'learning_rate': 0.20908000412787187}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:33,985] Trial 73 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 29, 'learning_rate': 0.004293510210083484}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:34,103] Trial 74 finished with value: 0.763386524822695 and parameters: {'n_estimators': 74, 'learning_rate': 0.13577271421051842}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:34,244] Trial 75 finished with value: 0.7465425531914894 and parameters: {'n_estimators': 97, 'learning_rate': 0.024144182212566402}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:34,332] Trial 76 finished with value: 0.7929078014184396 and parameters: {'n_estimators': 51, 'learning_rate': 0.7635060803383348}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:34,410] Trial 77 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 40, 'learning_rate': 0.010181517217181822}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:34,538] Trial 78 finished with value: 0.8055851063829786 and parameters: {'n_estimators': 86, 'learning_rate': 0.321967844425138}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:34,649] Trial 79 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 63, 'learning_rate': 0.0018105582430271226}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:34,695] Trial 80 finished with value: 0.750531914893617 and parameters: {'n_estimators': 17, 'learning_rate': 0.05725487884358381}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:34,745] Trial 81 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 20, 'learning_rate': 0.0022467900918126454}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:34,841] Trial 82 finished with value: 0.7672872340425532 and parameters: {'n_estimators': 66, 'learning_rate': 0.07104974114426789}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:34,982] Trial 83 finished with value: 0.750531914893617 and parameters: {'n_estimators': 88, 'learning_rate': 0.01263462917654469}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:35,059] Trial 84 finished with value: 0.7800531914893616 and parameters: {'n_estimators': 43, 'learning_rate': 0.39954205589498876}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:35,149] Trial 85 finished with value: 0.7505319148936169 and parameters: {'n_estimators': 54, 'learning_rate': 0.029961427410043647}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:35,298] Trial 86 finished with value: 0.8139184397163121 and parameters: {'n_estimators': 100, 'learning_rate': 0.9474635256553756}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:35,418] Trial 87 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 77, 'learning_rate': 0.005327978945865643}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:35,474] Trial 88 finished with value: 0.7716312056737589 and parameters: {'n_estimators': 32, 'learning_rate': 0.16848548794358392}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:35,531] Trial 89 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 26, 'learning_rate': 0.008204696109024995}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:35,650] Trial 90 finished with value: 0.7970744680851063 and parameters: {'n_estimators': 71, 'learning_rate': 0.2594552721404016}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:35,803] Trial 91 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 94, 'learning_rate': 0.0014590242156305613}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:35,879] Trial 92 finished with value: 0.738031914893617 and parameters: {'n_estimators': 49, 'learning_rate': 0.04613839682733216}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:35,968] Trial 93 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 37, 'learning_rate': 0.003459891660869934}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:36,097] Trial 94 finished with value: 0.7676418439716313 and parameters: {'n_estimators': 83, 'learning_rate': 0.10941138105771861}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:36,196] Trial 95 finished with value: 0.738031914893617 and parameters: {'n_estimators': 60, 'learning_rate': 0.019456400615886365}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:36,232] Trial 96 finished with value: 0.763563829787234 and parameters: {'n_estimators': 14, 'learning_rate': 0.6152654101490374}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:36,270] Trial 97 finished with value: 0.7168439716312056 and parameters: {'n_estimators': 13, 'learning_rate': 0.0025028654311746077}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:36,368] Trial 98 finished with value: 0.7757978723404255 and parameters: {'n_estimators': 59, 'learning_rate': 0.0791475543941116}. Best is trial 28 with value: 0.814095744680851.
# [I 2025-10-03 10:49:36,500] Trial 99 finished with value: 0.738031914893617 and parameters: {'n_estimators': 81, 'learning_rate': 0.014074646633398432}. Best is trial 28 with value: 0.814095744680851.
#
# Best Hyperparameters for AdaBoost: (Using QMCSampler)
# {'n_estimators': 46, 'learning_rate': 0.5232991146814947}

# %% [markdown]
# ### **4.7 Gradient Boosting Hyperparameter Tuning**

# %%
gradient_boosting = base_model_tuning('Gradient Boosting', X_train, y_train, iterations=OPTIMIZATION_ITERATIONS, metric_compare=OPTIMIZATION_METRIC)
# Out:
# C:\Users\azhar\AppData\Local\Temp\ipykernel_23760\1802863948.py:96: ExperimentalWarning: QMCSampler is experimental (supported from v3.0.0). The interface can change in the future.
#   study = opt.create_study(study_name='QMC Random Fine Tuning: Gradient Boosting', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
# [I 2025-10-03 10:49:36,518] A new study created in memory with name: QMC Random Fine Tuning: Gradient Boosting
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-10-03 10:49:36,603] Trial 0 finished with value: 0.7592198581560284 and parameters: {'max_features': 'log2', 'n_estimators': 64, 'learning_rate': 0.0020513382630874496, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 9, 'subsample': 0.8005575058716043}. Best is trial 0 with value: 0.7592198581560284.
# [W 2025-10-03 10:49:36,606] The parameter `max_features` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:36,632] Trial 1 finished with value: 0.52322695035461 and parameters: {'max_features': None, 'n_estimators': 10, 'learning_rate': 0.0010000000000000002, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'subsample': 0.5}. Best is trial 0 with value: 0.7592198581560284.
# [W 2025-10-03 10:49:36,634] The parameter `max_features` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:36,743] Trial 2 finished with value: 0.7717198581560284 and parameters: {'max_features': 'sqrt', 'n_estimators': 55, 'learning_rate': 0.010000000000000004, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 5, 'subsample': 0.75}. Best is trial 2 with value: 0.7717198581560284.
# [W 2025-10-03 10:49:36,745] The parameter `max_features` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:36,852] Trial 3 finished with value: 0.7460106382978723 and parameters: {'max_features': None, 'n_estimators': 78, 'learning_rate': 0.003162277660168382, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 8, 'subsample': 0.875}. Best is trial 2 with value: 0.7717198581560284.
# [W 2025-10-03 10:49:36,854] The parameter `max_features` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:36,921] Trial 4 finished with value: 0.7631205673758865 and parameters: {'max_features': None, 'n_estimators': 32, 'learning_rate': 0.03162277660168381, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 3, 'subsample': 0.625}. Best is trial 2 with value: 0.7717198581560284.
# [W 2025-10-03 10:49:36,923] The parameter `max_features` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:37,001] Trial 5 finished with value: 0.7673758865248227 and parameters: {'max_features': None, 'n_estimators': 44, 'learning_rate': 0.005623413251903492, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 4, 'subsample': 0.5625}. Best is trial 2 with value: 0.7717198581560284.
# [W 2025-10-03 10:49:37,003] The parameter `max_features` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:37,092] Trial 6 finished with value: 0.7969858156028369 and parameters: {'max_features': 'log2', 'n_estimators': 89, 'learning_rate': 0.05623413251903493, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 9, 'subsample': 0.8125}. Best is trial 6 with value: 0.7969858156028369.
# [W 2025-10-03 10:49:37,094] The parameter `max_features` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:37,193] Trial 7 finished with value: 0.746631205673759 and parameters: {'max_features': 'log2', 'n_estimators': 66, 'learning_rate': 0.0017782794100389236, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 7, 'subsample': 0.9375}. Best is trial 6 with value: 0.7969858156028369.
# [W 2025-10-03 10:49:37,195] The parameter `max_features` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:37,241] Trial 8 finished with value: 0.7674645390070922 and parameters: {'max_features': 'sqrt', 'n_estimators': 21, 'learning_rate': 0.01778279410038924, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2, 'subsample': 0.6875}. Best is trial 6 with value: 0.7969858156028369.
# [W 2025-10-03 10:49:37,242] The parameter `max_features` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:37,290] Trial 9 finished with value: 0.7381205673758865 and parameters: {'max_features': 'log2', 'n_estimators': 27, 'learning_rate': 0.004216965034285825, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 6, 'subsample': 0.65625}. Best is trial 6 with value: 0.7969858156028369.
# [W 2025-10-03 10:49:37,291] The parameter `max_features` in Trial#10 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:37,430] Trial 10 finished with value: 0.7546099290780142 and parameters: {'max_features': None, 'n_estimators': 72, 'learning_rate': 0.04216965034285825, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 1, 'subsample': 0.90625}. Best is trial 6 with value: 0.7969858156028369.
# [W 2025-10-03 10:49:37,432] The parameter `max_features` in Trial#11 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:37,611] Trial 11 finished with value: 0.7377659574468085 and parameters: {'max_features': None, 'n_estimators': 95, 'learning_rate': 0.0013335214321633238, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 4, 'subsample': 0.78125}. Best is trial 6 with value: 0.7969858156028369.
# [W 2025-10-03 10:49:37,613] The parameter `max_features` in Trial#12 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:37,670] Trial 12 finished with value: 0.8013297872340426 and parameters: {'max_features': 'log2', 'n_estimators': 49, 'learning_rate': 0.013335214321633242, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 9, 'subsample': 0.53125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:37,672] The parameter `max_features` in Trial#13 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:37,720] Trial 13 finished with value: 0.7130319148936171 and parameters: {'max_features': 'sqrt', 'n_estimators': 38, 'learning_rate': 0.002371373705661656, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 10, 'subsample': 0.71875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:37,722] The parameter `max_features` in Trial#14 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:37,923] Trial 14 finished with value: 0.737854609929078 and parameters: {'max_features': None, 'n_estimators': 83, 'learning_rate': 0.023713737056616564, 'max_depth': 9, 'min_samples_split': 2, 'min_samples_leaf': 5, 'subsample': 0.96875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:37,925] The parameter `max_features` in Trial#15 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:38,006] Trial 15 finished with value: 0.7928191489361702 and parameters: {'max_features': 'log2', 'n_estimators': 61, 'learning_rate': 0.007498942093324564, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 2, 'subsample': 0.84375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:38,007] The parameter `max_features` in Trial#16 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:38,044] Trial 16 finished with value: 0.7757978723404255 and parameters: {'max_features': 'log2', 'n_estimators': 15, 'learning_rate': 0.07498942093324566, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 7, 'subsample': 0.59375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:38,044] The parameter `max_features` in Trial#17 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:38,103] Trial 17 finished with value: 0.7041666666666667 and parameters: {'max_features': None, 'n_estimators': 18, 'learning_rate': 0.008659643233600654, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 3, 'subsample': 0.984375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:38,104] The parameter `max_features` in Trial#18 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:38,201] Trial 18 finished with value: 0.7717198581560284 and parameters: {'max_features': None, 'n_estimators': 64, 'learning_rate': 0.08659643233600657, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 8, 'subsample': 0.734375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:38,203] The parameter `max_features` in Trial#19 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:38,301] Trial 19 finished with value: 0.7717198581560284 and parameters: {'max_features': None, 'n_estimators': 86, 'learning_rate': 0.0027384196342643626, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 6, 'subsample': 0.609375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:38,303] The parameter `max_features` in Trial#20 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:38,411] Trial 20 finished with value: 0.7886524822695036 and parameters: {'max_features': 'log2', 'n_estimators': 41, 'learning_rate': 0.027384196342643632, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 1, 'subsample': 0.859375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:38,412] The parameter `max_features` in Trial#21 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:38,584] Trial 21 finished with value: 0.7340425531914894 and parameters: {'max_features': 'sqrt', 'n_estimators': 52, 'learning_rate': 0.0015399265260594922, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.921875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:38,586] The parameter `max_features` in Trial#22 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:38,705] Trial 22 finished with value: 0.7928191489361702 and parameters: {'max_features': 'log2', 'n_estimators': 98, 'learning_rate': 0.015399265260594926, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 7, 'subsample': 0.671875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:38,707] The parameter `max_features` in Trial#23 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:38,785] Trial 23 finished with value: 0.7885638297872339 and parameters: {'max_features': 'log2', 'n_estimators': 75, 'learning_rate': 0.004869675251658635, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 10, 'subsample': 0.546875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:38,785] The parameter `max_features` in Trial#24 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:38,843] Trial 24 finished with value: 0.7759751773049646 and parameters: {'max_features': None, 'n_estimators': 29, 'learning_rate': 0.04869675251658634, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 5, 'subsample': 0.796875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:38,843] The parameter `max_features` in Trial#25 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:38,891] Trial 25 finished with value: 0.5317375886524822 and parameters: {'max_features': 'sqrt', 'n_estimators': 24, 'learning_rate': 0.0020535250264571477, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 9, 'subsample': 0.828125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:38,893] The parameter `max_features` in Trial#26 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:38,971] Trial 26 finished with value: 0.7885638297872339 and parameters: {'max_features': None, 'n_estimators': 69, 'learning_rate': 0.020535250264571474, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 4, 'subsample': 0.578125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:38,973] The parameter `max_features` in Trial#27 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:39,154] Trial 27 finished with value: 0.7844858156028369 and parameters: {'max_features': 'log2', 'n_estimators': 92, 'learning_rate': 0.0064938163157621165, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 1, 'subsample': 0.703125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:39,154] The parameter `max_features` in Trial#28 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:39,233] Trial 28 finished with value: 0.7546099290780142 and parameters: {'max_features': None, 'n_estimators': 46, 'learning_rate': 0.06493816315762117, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 6, 'subsample': 0.953125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:39,234] The parameter `max_features` in Trial#29 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:39,293] Trial 29 finished with value: 0.7678191489361701 and parameters: {'max_features': 'log2', 'n_estimators': 35, 'learning_rate': 0.0036517412725483775, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 8, 'subsample': 0.765625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:39,293] The parameter `max_features` in Trial#30 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:39,412] Trial 30 finished with value: 0.8013297872340426 and parameters: {'max_features': 'sqrt', 'n_estimators': 81, 'learning_rate': 0.03651741272548378, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 3, 'subsample': 0.515625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:39,413] The parameter `max_features` in Trial#31 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:39,523] Trial 31 finished with value: 0.725531914893617 and parameters: {'max_features': None, 'n_estimators': 58, 'learning_rate': 0.0011547819846894588, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 5, 'subsample': 0.640625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:39,523] The parameter `max_features` in Trial#32 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:39,561] Trial 32 finished with value: 0.7506205673758864 and parameters: {'max_features': None, 'n_estimators': 12, 'learning_rate': 0.01154781984689459, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 10, 'subsample': 0.890625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:39,561] The parameter `max_features` in Trial#33 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:39,609] Trial 33 finished with value: 0.6785460992907801 and parameters: {'max_features': None, 'n_estimators': 14, 'learning_rate': 0.003398208328942561, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 2, 'subsample': 0.9609375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:39,609] The parameter `max_features` in Trial#34 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:39,689] Trial 34 finished with value: 0.7716312056737589 and parameters: {'max_features': None, 'n_estimators': 59, 'learning_rate': 0.03398208328942562, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 7, 'subsample': 0.7109375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:39,689] The parameter `max_features` in Trial#35 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:39,778] Trial 35 finished with value: 0.6960106382978724 and parameters: {'max_features': 'log2', 'n_estimators': 82, 'learning_rate': 0.0010746078283213173, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 9, 'subsample': 0.5859375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:39,778] The parameter `max_features` in Trial#36 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:39,867] Trial 36 finished with value: 0.7718085106382978 and parameters: {'max_features': 'log2', 'n_estimators': 37, 'learning_rate': 0.010746078283213186, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 4, 'subsample': 0.8359375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:39,869] The parameter `max_features` in Trial#37 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:39,926] Trial 37 finished with value: 0.7297872340425531 and parameters: {'max_features': 'log2', 'n_estimators': 48, 'learning_rate': 0.001910952974970441, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 3, 'subsample': 0.8984375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:39,928] The parameter `max_features` in Trial#38 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:40,036] Trial 38 finished with value: 0.7927304964539007 and parameters: {'max_features': 'log2', 'n_estimators': 93, 'learning_rate': 0.019109529749704413, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 8, 'subsample': 0.6484375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:40,038] The parameter `max_features` in Trial#39 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:40,136] Trial 39 finished with value: 0.7715425531914895 and parameters: {'max_features': None, 'n_estimators': 71, 'learning_rate': 0.006042963902381328, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 6, 'subsample': 0.5234375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:40,136] The parameter `max_features` in Trial#40 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:40,195] Trial 40 finished with value: 0.7677304964539007 and parameters: {'max_features': 'log2', 'n_estimators': 25, 'learning_rate': 0.06042963902381334, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 1, 'subsample': 0.7734375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:40,198] The parameter `max_features` in Trial#41 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:40,244] Trial 41 finished with value: 0.527482269503546 and parameters: {'max_features': 'sqrt', 'n_estimators': 31, 'learning_rate': 0.0014330125702369636, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 8, 'subsample': 0.8671875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:40,246] The parameter `max_features` in Trial#42 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:40,407] Trial 42 finished with value: 0.7673758865248227 and parameters: {'max_features': None, 'n_estimators': 76, 'learning_rate': 0.014330125702369625, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 3, 'subsample': 0.6171875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:40,408] The parameter `max_features` in Trial#43 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:40,517] Trial 43 finished with value: 0.7631205673758865 and parameters: {'max_features': None, 'n_estimators': 99, 'learning_rate': 0.004531583637600819, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 5, 'subsample': 0.7421875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:40,519] The parameter `max_features` in Trial#44 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:40,597] Trial 44 finished with value: 0.7886524822695036 and parameters: {'max_features': 'log2', 'n_estimators': 54, 'learning_rate': 0.045315836376008195, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 10, 'subsample': 0.9921875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:40,600] The parameter `max_features` in Trial#45 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:40,669] Trial 45 finished with value: 0.7801418439716311 and parameters: {'max_features': 'log2', 'n_estimators': 42, 'learning_rate': 0.008058421877614822, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 9, 'subsample': 0.8046875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:40,670] The parameter `max_features` in Trial#46 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:40,799] Trial 46 finished with value: 0.7844858156028369 and parameters: {'max_features': None, 'n_estimators': 88, 'learning_rate': 0.08058421877614824, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 4, 'subsample': 0.5546875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:40,799] The parameter `max_features` in Trial#47 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:40,950] Trial 47 finished with value: 0.7590425531914893 and parameters: {'max_features': 'sqrt', 'n_estimators': 65, 'learning_rate': 0.0025482967479793462, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 1, 'subsample': 0.6796875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:40,950] The parameter `max_features` in Trial#48 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:40,989] Trial 48 finished with value: 0.7801418439716312 and parameters: {'max_features': 'sqrt', 'n_estimators': 19, 'learning_rate': 0.02548296747979348, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 6, 'subsample': 0.9296875}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:40,991] The parameter `max_features` in Trial#49 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:41,027] Trial 49 finished with value: 0.5655141843971631 and parameters: {'max_features': 'log2', 'n_estimators': 17, 'learning_rate': 0.0029427271762092824, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 5, 'subsample': 0.5390625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:41,027] The parameter `max_features` in Trial#50 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:41,105] Trial 50 finished with value: 0.801241134751773 and parameters: {'max_features': 'log2', 'n_estimators': 62, 'learning_rate': 0.02942727176209283, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 10, 'subsample': 0.7890625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:41,107] The parameter `max_features` in Trial#51 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:41,216] Trial 51 finished with value: 0.775886524822695 and parameters: {'max_features': 'sqrt', 'n_estimators': 85, 'learning_rate': 0.009305720409296989, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 7, 'subsample': 0.9140625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:41,217] The parameter `max_features` in Trial#52 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:41,264] Trial 52 finished with value: 0.7929078014184396 and parameters: {'max_features': 'sqrt', 'n_estimators': 39, 'learning_rate': 0.09305720409296998, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 2, 'subsample': 0.6640625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:41,264] The parameter `max_features` in Trial#53 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:41,343] Trial 53 finished with value: 0.7843085106382979 and parameters: {'max_features': 'sqrt', 'n_estimators': 51, 'learning_rate': 0.005232991146814949, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 1, 'subsample': 0.6015625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:41,343] The parameter `max_features` in Trial#54 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:41,515] Trial 54 finished with value: 0.7801418439716312 and parameters: {'max_features': None, 'n_estimators': 96, 'learning_rate': 0.052329911468149505, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 6, 'subsample': 0.8515625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:41,515] The parameter `max_features` in Trial#55 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:41,604] Trial 55 finished with value: 0.7507978723404255 and parameters: {'max_features': 'log2', 'n_estimators': 73, 'learning_rate': 0.0016548170999431814, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 8, 'subsample': 0.9765625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:41,604] The parameter `max_features` in Trial#56 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:41,684] Trial 56 finished with value: 0.7588652482269502 and parameters: {'max_features': None, 'n_estimators': 28, 'learning_rate': 0.01654817099943183, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.7265625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:41,684] The parameter `max_features` in Trial#57 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:41,722] Trial 57 finished with value: 0.7592198581560284 and parameters: {'max_features': 'log2', 'n_estimators': 22, 'learning_rate': 0.006978305848598664, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 10, 'subsample': 0.6328125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:41,722] The parameter `max_features` in Trial#58 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:41,862] Trial 58 finished with value: 0.7546985815602838 and parameters: {'max_features': None, 'n_estimators': 68, 'learning_rate': 0.06978305848598666, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 5, 'subsample': 0.8828125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:41,862] The parameter `max_features` in Trial#59 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:42,013] Trial 59 finished with value: 0.7675531914893616 and parameters: {'max_features': 'sqrt', 'n_estimators': 91, 'learning_rate': 0.002206734069084591, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.7578125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:42,014] The parameter `max_features` in Trial#60 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# ...
# [I 2025-10-03 10:49:43,772] Trial 80 finished with value: 0.7717198581560284 and parameters: {'max_features': 'log2', 'n_estimators': 17, 'learning_rate': 0.01485508017172776, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 1, 'subsample': 0.62890625}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:43,774] The parameter `max_features` in Trial#81 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:43,811] Trial 81 finished with value: 0.52322695035461 and parameters: {'max_features': 'sqrt', 'n_estimators': 20, 'learning_rate': 0.0017154378963428801, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 10, 'subsample': 0.76953125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:43,812] The parameter `max_features` in Trial#82 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:43,901] Trial 82 finished with value: 0.788563829787234 and parameters: {'max_features': 'sqrt', 'n_estimators': 66, 'learning_rate': 0.017154378963428803, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 5, 'subsample': 0.51953125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:43,903] The parameter `max_features` in Trial#83 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:44,118] Trial 83 finished with value: 0.7801418439716312 and parameters: {'max_features': 'log2', 'n_estimators': 88, 'learning_rate': 0.005424690937011328, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 2, 'subsample': 0.64453125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:44,120] The parameter `max_features` in Trial#84 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:44,199] Trial 84 finished with value: 0.775886524822695 and parameters: {'max_features': None, 'n_estimators': 43, 'learning_rate': 0.05424690937011329, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 7, 'subsample': 0.89453125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:44,200] The parameter `max_features` in Trial#85 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:44,269] Trial 85 finished with value: 0.7884751773049645 and parameters: {'max_features': 'sqrt', 'n_estimators': 54, 'learning_rate': 0.009646616199111998, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 6, 'subsample': 0.83203125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:44,271] The parameter `max_features` in Trial#86 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:44,493] Trial 86 finished with value: 0.7972517730496455 and parameters: {'max_features': 'sqrt', 'n_estimators': 100, 'learning_rate': 0.09646616199112, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 1, 'subsample': 0.58203125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:44,495] The parameter `max_features` in Trial#87 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:44,603] Trial 87 finished with value: 0.7929078014184396 and parameters: {'max_features': 'sqrt', 'n_estimators': 77, 'learning_rate': 0.003050527890267026, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 4, 'subsample': 0.70703125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:44,605] The parameter `max_features` in Trial#88 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:44,662] Trial 88 finished with value: 0.7419326241134752 and parameters: {'max_features': None, 'n_estimators': 32, 'learning_rate': 0.030505278902670276, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 9, 'subsample': 0.95703125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:44,664] The parameter `max_features` in Trial#89 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:44,721] Trial 89 finished with value: 0.73395390070922 and parameters: {'max_features': 'sqrt', 'n_estimators': 26, 'learning_rate': 0.0040679443210830495, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 5, 'subsample': 0.92578125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:44,723] The parameter `max_features` in Trial#90 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:44,802] Trial 90 finished with value: 0.797340425531915 and parameters: {'max_features': 'sqrt', 'n_estimators': 71, 'learning_rate': 0.04067944321083049, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 10, 'subsample': 0.67578125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:44,803] The parameter `max_features` in Trial#91 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:44,891] Trial 91 finished with value: 0.7425531914893616 and parameters: {'max_features': 'log2', 'n_estimators': 94, 'learning_rate': 0.0012863969449369746, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 8, 'subsample': 0.55078125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:44,893] The parameter `max_features` in Trial#92 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:44,990] Trial 92 finished with value: 0.7335106382978723 and parameters: {'max_features': None, 'n_estimators': 49, 'learning_rate': 0.01286396944936975, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 3, 'subsample': 0.80078125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:44,991] The parameter `max_features` in Trial#93 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:45,089] Trial 93 finished with value: 0.7252659574468086 and parameters: {'max_features': None, 'n_estimators': 37, 'learning_rate': 0.0022875732003183966, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 2, 'subsample': 0.98828125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:45,091] The parameter `max_features` in Trial#94 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:45,190] Trial 94 finished with value: 0.7674645390070923 and parameters: {'max_features': 'log2', 'n_estimators': 83, 'learning_rate': 0.02287573200318397, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 7, 'subsample': 0.73828125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:45,193] The parameter `max_features` in Trial#95 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:45,260] Trial 95 finished with value: 0.7801418439716312 and parameters: {'max_features': 'log2', 'n_estimators': 60, 'learning_rate': 0.007233941627366754, 'max_depth': 8, 'min_samples_split': 8, 'min_samples_leaf': 9, 'subsample': 0.61328125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:45,261] The parameter `max_features` in Trial#96 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:45,298] Trial 96 finished with value: 0.7207446808510638 and parameters: {'max_features': None, 'n_estimators': 14, 'learning_rate': 0.0723394162736675, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 4, 'subsample': 0.86328125}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:45,299] The parameter `max_features` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:45,337] Trial 97 finished with value: 0.52322695035461 and parameters: {'max_features': 'log2', 'n_estimators': 13, 'learning_rate': 0.0018434229924091112, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 6, 'subsample': 0.80859375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:45,339] The parameter `max_features` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:45,458] Trial 98 finished with value: 0.7632978723404256 and parameters: {'max_features': None, 'n_estimators': 59, 'learning_rate': 0.018434229924091116, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1, 'subsample': 0.55859375}. Best is trial 12 with value: 0.8013297872340426.
# [W 2025-10-03 10:49:45,460] The parameter `max_features` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:45,569] Trial 99 finished with value: 0.750354609929078 and parameters: {'max_features': None, 'n_estimators': 81, 'learning_rate': 0.005829415347136074, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 3, 'subsample': 0.68359375}. Best is trial 12 with value: 0.8013297872340426.
#
# Best Hyperparameters for Gradient Boosting: (Using QMCSampler)
# {'max_features': 'log2', 'n_estimators': 49, 'learning_rate': 0.013335214321633242, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 9, 'subsample': 0.53125}

# %% [markdown]
# ### **4.8 Save Best Model for each Base Models**

# %%
# Final Base Model Fitting
base_logistic_regression = logistic_regression.fit(X_train, y_train)
base_decision_tree = decision_tree.fit(X_train, y_train)
base_random_forest = random_forest.fit(X_train, y_train)
base_knn = knn.fit(X_train, y_train)
base_svm = svm.fit(X_train, y_train)
base_adaboost = adaboost.fit(X_train, y_train)
base_gradient_boosting = gradient_boosting.fit(X_train, y_train)

# End timing base models training
base_models_training_end = time.time()

# Save base models total training time
base_models_training_time = base_models_training_end - base_models_training_start

# Base Models Storage
base_models = {
    'Logistic Regression': base_logistic_regression,
    'Decision Tree': base_decision_tree,
    'Random Forest': base_random_forest,
    'K-Nearest Neighbors': base_knn,
    'Support Vector Machine': base_svm,
    'AdaBoost': base_adaboost,
    'Gradient Boosting': base_gradient_boosting
}

# Show Base Model Hyperparameters
base_model_hyperparameters = pd.DataFrame(columns=['Model Name', 'Best Hyperparameters'])
base_model_hyperparameters['Model Name'] = [
                                        'Logistic Regression', 
                                        'Decision Tree', 
                                        'Random Forest', 
                                        'K-Nearest Neighbors', 
                                        'Support Vector Machine', 
                                        'AdaBoost', 
                                        'Gradient Boosting'
                                        ]
base_model_hyperparameters['Best Hyperparameters'] = [   
                                                base_logistic_regression.get_params(),
                                                base_decision_tree.get_params(), 
                                                base_random_forest.get_params(), 
                                                base_knn.get_params(), 
                                                base_svm.get_params(), 
                                                base_adaboost.get_params(), 
                                                base_gradient_boosting.get_params(),
                                                ]

base_model_hyperparameters
# Out:
#                Model Name                               Best Hyperparameters
# 0     Logistic Regression  {'C': 1.6548170999431808, 'class_weight': None...
# 1           Decision Tree  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 2           Random Forest  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# 3     K-Nearest Neighbors  {'algorithm': 'kd_tree', 'leaf_size': 30, 'met...
# 4  Support Vector Machine  {'C': 0.006978305848598664, 'break_ties': Fals...
# 5                AdaBoost  {'algorithm': 'deprecated', 'estimator': None,...
# 6       Gradient Boosting  {'ccp_alpha': 0.0, 'criterion': 'friedman_mse'...

# %% [markdown]
# ## **5. Meta Model Hyperparameter Tuning with QMC-RS and Cross Validation**

# %% [markdown]
# The hyperparameters to be tuned are:
# - Selection of the number and type of base models used
# - Number of layers in the neural network: 1 - 5
# - Number of neurons per layer: 10 - 100
# - Learning rate behavior: Constant or Adaptive
# - Learning rate value: 0.0001 - 0.01
# - L2 Regularization value: 0.0001 - 0.01
#
# Unchanged Preset hyperparameters:
# - Activation function: ReLU
# - Optimizer (Solver): Adam
# - Epochs (Max Iter): 300

# %%
# Meta Model (Stacking with MLP) Hyperparameter Tuning with QMC-RS and CV Function
def meta_model_tuning(models, x_train, y_train, x_test, y_test, iterations=100):
    def objective(trial):
        # Suggest which base models to include
        selected_estimators = []
        for name, model in models.items():
            use_model = trial.suggest_categorical(f'use_{name}', [True, False])
            if use_model:
                selected_estimators.append((name, model))
        # At least 2 base models required for stacking
        if len(selected_estimators) < 2:
            return 0.0

        n_layers = trial.suggest_int('n_layers', 1, 5)
        neurons = [trial.suggest_int(f'n_neurons_{i}', 10, 100) for i in range(n_layers)]
        learning_rate = trial.suggest_categorical('learning_rate', ['constant', 'adaptive'])
        learning_rate_init = trial.suggest_float('learning_rate_init', 0.0001, 0.01, log=True)
        alpha = trial.suggest_float('alpha', 0.0001, 0.01, log=True)

        meta_model = MLPClassifier(
            activation='relu',
            solver='adam',
            hidden_layer_sizes=tuple(neurons),
            learning_rate=learning_rate,
            learning_rate_init=learning_rate_init,
            alpha=alpha,
            max_iter=300,
            random_state=RANDOM_STATE
        )

        stacking_model = StackingClassifier(
            estimators=selected_estimators,
            final_estimator=meta_model,
            cv=CV_FOLDS,
            n_jobs=N_JOBS
        )

        stacking_model.fit(x_train, y_train)
        y_pred = stacking_model.predict(x_test)
        return accuracy_score(y_test, y_pred)

    study = opt.create_study(study_name='Meta Model Fine Tuning: Stacking with MLP (QMC Random Search)', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
    study.optimize(objective, n_trials=iterations, n_jobs=1, show_progress_bar=True)
    best_params = study.best_params

    # Get selected estimators from best_params
    best_selected_estimators = []
    for name, model in models.items():
        if best_params.get(f'use_{name}', False):
            best_selected_estimators.append((name, model))
            
    n_layers = best_params.pop('n_layers')
    hidden_layer_sizes = tuple(best_params.pop(f'n_neurons_{i}') for i in range(n_layers))
    best_params['hidden_layer_sizes'] = hidden_layer_sizes

    # Define the final meta model
    mlp_params = {k: v for k, v in best_params.items() if not k.startswith('use_')}
    best_meta_model = MLPClassifier(**mlp_params, activation='relu', solver='adam', max_iter=300, random_state=RANDOM_STATE)

    # Create the final stacking model using best_selected_estimators
    best_stacking_model = StackingClassifier(estimators=best_selected_estimators, final_estimator=best_meta_model, cv=CV_FOLDS, n_jobs=N_JOBS)

    print('\nBest Meta Model Hyperparameters:')
    print(best_meta_model.get_params())
    print('\nSelected Base Models for Stacking:')
    for name, _ in best_selected_estimators:
        print(f'- {name}')

    return best_stacking_model

# %%
# Begin timing meta model training
meta_model_training_start = time.time()

# Meta Model Tuning and Final Stacking Model Fitting
sel_nnml = meta_model_tuning(base_models, X_train, y_train, X_test, y_test, iterations=OPTIMIZATION_ITERATIONS)
sel_nnml.fit(X_train, y_train)

# End timing meta model training
meta_model_training_end = time.time()

# Save meta model training time
meta_model_training_time = meta_model_training_end - meta_model_training_start
# Out:
# C:\Users\azhar\AppData\Local\Temp\ipykernel_23760\434471935.py:42: ExperimentalWarning: QMCSampler is experimental (supported from v3.0.0). The interface can change in the future.
#   study = opt.create_study(study_name='Meta Model Fine Tuning: Stacking with MLP (QMC Random Search)', direction='maximize', sampler=opt.samplers.QMCSampler(seed=RANDOM_STATE))
# [I 2025-10-03 10:49:45,863] A new study created in memory with name: Meta Model Fine Tuning: Stacking with MLP (QMC Random Search)
#   0%|          | 0/100 [00:00<?, ?it/s]
# c:\Users\azhar\miniconda3\envs\ml_kit\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-10-03 10:49:46,684] Trial 0 finished with value: 0.7833333333333333 and parameters: {'use_Logistic Regression': False, 'use_Decision Tree': True, 'use_Random Forest': True, 'use_K-Nearest Neighbors': False, 'use_Support Vector Machine': False, 'use_AdaBoost': False, 'use_Gradient Boosting': True, 'n_layers': 1, 'n_neurons_0': 26, 'learning_rate': 'adaptive', 'learning_rate_init': 0.0007309539835912913, 'alpha': 0.0003823475224675188}. Best is trial 0 with value: 0.7833333333333333.
# [W 2025-10-03 10:49:46,686] The parameter `use_Logistic Regression` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:46,687] The parameter `use_Decision Tree` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:46,687] The parameter `use_Random Forest` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:46,688] The parameter `use_K-Nearest Neighbors` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:46,689] The parameter `use_Support Vector Machine` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:46,689] The parameter `use_AdaBoost` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:46,689] The parameter `use_Gradient Boosting` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:46,690] The parameter `learning_rate` in Trial#1 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# c:\Users\azhar\miniconda3\envs\ml_kit\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-10-03 10:49:47,379] Trial 1 finished with value: 0.4 and parameters: {'use_Logistic Regression': True, 'use_Decision Tree': False, 'use_Random Forest': False, 'use_K-Nearest Neighbors': False, 'use_Support Vector Machine': True, 'use_AdaBoost': True, 'use_Gradient Boosting': False, 'n_layers': 1, 'n_neurons_0': 10, 'learning_rate': 'constant', 'learning_rate_init': 0.00010000000000000009, 'alpha': 0.00010000000000000009}. Best is trial 0 with value: 0.7833333333333333.
# [W 2025-10-03 10:49:47,382] The parameter `use_Logistic Regression` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,384] The parameter `use_Decision Tree` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,384] The parameter `use_Random Forest` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,385] The parameter `use_K-Nearest Neighbors` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,385] The parameter `use_Support Vector Machine` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,386] The parameter `use_AdaBoost` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,386] The parameter `use_Gradient Boosting` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,387] The parameter `n_neurons_1` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,387] The parameter `n_neurons_2` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,388] The parameter `learning_rate` in Trial#2 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:47,836] Trial 2 finished with value: 0.8333333333333334 and parameters: {'use_Logistic Regression': True, 'use_Decision Tree': True, 'use_Random Forest': False, 'use_K-Nearest Neighbors': False, 'use_Support Vector Machine': False, 'use_AdaBoost': False, 'use_Gradient Boosting': True, 'n_layers': 3, 'n_neurons_0': 55, 'n_neurons_1': 98, 'n_neurons_2': 80, 'learning_rate': 'constant', 'learning_rate_init': 0.0010000000000000002, 'alpha': 0.0010000000000000002}. Best is trial 2 with value: 0.8333333333333334.
# [W 2025-10-03 10:49:47,838] The parameter `use_Logistic Regression` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,838] The parameter `use_Decision Tree` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,838] The parameter `use_Random Forest` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,840] The parameter `use_K-Nearest Neighbors` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,841] The parameter `use_Support Vector Machine` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,842] The parameter `use_AdaBoost` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,842] The parameter `use_Gradient Boosting` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,842] The parameter `n_neurons_1` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,844] The parameter `n_neurons_2` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,844] The parameter `n_neurons_3` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:47,845] The parameter `learning_rate` in Trial#3 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:48,127] Trial 3 finished with value: 0.9 and parameters: {'use_Logistic Regression': False, 'use_Decision Tree': False, 'use_Random Forest': False, 'use_K-Nearest Neighbors': True, 'use_Support Vector Machine': True, 'use_AdaBoost': False, 'use_Gradient Boosting': False, 'n_layers': 4, 'n_neurons_0': 32, 'n_neurons_1': 16, 'n_neurons_2': 99, 'n_neurons_3': 80, 'learning_rate': 'constant', 'learning_rate_init': 0.0003162277660168384, 'alpha': 0.0003162277660168384}. Best is trial 3 with value: 0.9.
# [W 2025-10-03 10:49:48,130] The parameter `use_Logistic Regression` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,131] The parameter `use_Decision Tree` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,131] The parameter `use_Random Forest` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,131] The parameter `use_K-Nearest Neighbors` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,131] The parameter `use_Support Vector Machine` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,134] The parameter `use_AdaBoost` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,134] The parameter `use_Gradient Boosting` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,135] The parameter `n_neurons_1` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,135] The parameter `learning_rate` in Trial#4 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:48,256] Trial 4 finished with value: 0.8833333333333333 and parameters: {'use_Logistic Regression': True, 'use_Decision Tree': False, 'use_Random Forest': False, 'use_K-Nearest Neighbors': False, 'use_Support Vector Machine': True, 'use_AdaBoost': False, 'use_Gradient Boosting': False, 'n_layers': 2, 'n_neurons_0': 78, 'n_neurons_1': 68, 'learning_rate': 'constant', 'learning_rate_init': 0.003162277660168382, 'alpha': 0.003162277660168382}. Best is trial 3 with value: 0.9.
# [W 2025-10-03 10:49:48,262] The parameter `use_Logistic Regression` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,263] The parameter `use_Decision Tree` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,264] The parameter `use_Random Forest` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,264] The parameter `use_K-Nearest Neighbors` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,265] The parameter `use_Support Vector Machine` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,265] The parameter `use_AdaBoost` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,265] The parameter `use_Gradient Boosting` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,265] The parameter `n_neurons_1` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:48,265] The parameter `learning_rate` in Trial#5 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:49,025] Trial 5 finished with value: 0.8333333333333334 and parameters: {'use_Logistic Regression': False, 'use_Decision Tree': True, 'use_Random Forest': True, 'use_K-Nearest Neighbors': True, 'use_Support Vector Machine': False, 'use_AdaBoost': False, 'use_Gradient Boosting': False, 'n_layers': 2, 'n_neurons_0': 44, 'n_neurons_1': 92, 'learning_rate': 'adaptive', 'learning_rate_init': 0.0017782794100389236, 'alpha': 0.005623413251903492}. Best is trial 3 with value: 0.9.
# [W 2025-10-03 10:49:49,029] The parameter `use_Logistic Regression` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,030] The parameter `use_Decision Tree` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,030] The parameter `use_Random Forest` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,030] The parameter `use_K-Nearest Neighbors` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,030] The parameter `use_Support Vector Machine` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,030] The parameter `use_AdaBoost` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,030] The parameter `use_Gradient Boosting` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,032] The parameter `n_neurons_1` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,033] The parameter `n_neurons_2` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,033] The parameter `n_neurons_3` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,034] The parameter `n_neurons_4` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,035] The parameter `learning_rate` in Trial#6 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:49,582] Trial 6 finished with value: 0.9 and parameters: {'use_Logistic Regression': True, 'use_Decision Tree': False, 'use_Random Forest': False, 'use_K-Nearest Neighbors': True, 'use_Support Vector Machine': True, 'use_AdaBoost': False, 'use_Gradient Boosting': False, 'n_layers': 5, 'n_neurons_0': 89, 'n_neurons_1': 91, 'n_neurons_2': 38, 'n_neurons_3': 20, 'n_neurons_4': 30, 'learning_rate': 'adaptive', 'learning_rate_init': 0.00017782794100389232, 'alpha': 0.0005623413251903495}. Best is trial 3 with value: 0.9.
# [W 2025-10-03 10:49:49,586] The parameter `use_Logistic Regression` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,587] The parameter `use_Decision Tree` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,587] The parameter `use_Random Forest` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,588] The parameter `use_K-Nearest Neighbors` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,588] The parameter `use_Support Vector Machine` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,589] The parameter `use_AdaBoost` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,590] The parameter `use_Gradient Boosting` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,590] The parameter `n_neurons_1` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,590] The parameter `n_neurons_2` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,591] The parameter `n_neurons_3` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:49,591] The parameter `learning_rate` in Trial#7 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:50,342] Trial 7 finished with value: 0.85 and parameters: {'use_Logistic Regression': True, 'use_Decision Tree': True, 'use_Random Forest': True, 'use_K-Nearest Neighbors': False, 'use_Support Vector Machine': False, 'use_AdaBoost': True, 'use_Gradient Boosting': True, 'n_layers': 4, 'n_neurons_0': 21, 'n_neurons_1': 32, 'n_neurons_2': 55, 'n_neurons_3': 37, 'learning_rate': 'constant', 'learning_rate_init': 0.005623413251903492, 'alpha': 0.0017782794100389236}. Best is trial 3 with value: 0.9.
# [W 2025-10-03 10:49:50,344] The parameter `use_Logistic Regression` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:50,346] The parameter `use_Decision Tree` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:50,347] The parameter `use_Random Forest` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:50,347] The parameter `use_K-Nearest Neighbors` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:50,348] The parameter `use_Support Vector Machine` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:50,348] The parameter `use_AdaBoost` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:50,349] The parameter `use_Gradient Boosting` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:50,349] The parameter `learning_rate` in Trial#8 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:51,144] Trial 8 finished with value: 0.85 and parameters: {'use_Logistic Regression': True, 'use_Decision Tree': False, 'use_Random Forest': True, 'use_K-Nearest Neighbors': False, 'use_Support Vector Machine': True, 'use_AdaBoost': False, 'use_Gradient Boosting': False, 'n_layers': 1, 'n_neurons_0': 66, 'learning_rate': 'adaptive', 'learning_rate_init': 0.0005623413251903495, 'alpha': 0.00017782794100389232}. Best is trial 3 with value: 0.9.
# [W 2025-10-03 10:49:51,146] The parameter `use_Logistic Regression` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:51,148] The parameter `use_Decision Tree` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:51,148] The parameter `use_Random Forest` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:51,149] The parameter `use_K-Nearest Neighbors` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:51,149] The parameter `use_Support Vector Machine` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:51,150] The parameter `use_AdaBoost` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:51,150] The parameter `use_Gradient Boosting` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:49:51,151] The parameter `learning_rate` in Trial#9 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:49:51,868] Trial 9 finished with value: 0.9 and parameters: {'use_Logistic Regression': True, 'use_Decision Tree': False, 'use_Random Forest': True, 'use_K-Nearest Neighbors': False, 'use_Support Vector Machine': True, 'use_AdaBoost': True, 'use_Gradient Boosting': True, 'n_layers': 1, 'n_neurons_0': 38, 'learning_rate': 'constant', 'learning_rate_init': 0.007498942093324564, 'alpha': 0.0007498942093324562}. Best is trial 3 with value: 0.9.
# [W 2025-10-03 10:49:51,872] The parameter `use_Logistic Regression` in Trial#10 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# ...
# [W 2025-10-03 10:50:53,138] The parameter `use_Decision Tree` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:53,139] The parameter `use_Random Forest` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:53,140] The parameter `use_K-Nearest Neighbors` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:53,140] The parameter `use_Support Vector Machine` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:53,141] The parameter `use_AdaBoost` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:53,142] The parameter `use_Gradient Boosting` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:53,142] The parameter `learning_rate` in Trial#97 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# c:\Users\azhar\miniconda3\envs\ml_kit\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2025-10-03 10:50:54,394] Trial 97 finished with value: 0.85 and parameters: {'use_Logistic Regression': True, 'use_Decision Tree': True, 'use_Random Forest': True, 'use_K-Nearest Neighbors': True, 'use_Support Vector Machine': True, 'use_AdaBoost': False, 'use_Gradient Boosting': False, 'n_layers': 1, 'n_neurons_0': 22, 'learning_rate': 'adaptive', 'learning_rate_init': 0.0006264335366568858, 'alpha': 0.0005048065716667477}. Best is trial 3 with value: 0.9.
# [W 2025-10-03 10:50:54,397] The parameter `use_Logistic Regression` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,400] The parameter `use_Decision Tree` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,401] The parameter `use_Random Forest` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,402] The parameter `use_K-Nearest Neighbors` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,402] The parameter `use_Support Vector Machine` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,404] The parameter `use_AdaBoost` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,404] The parameter `use_Gradient Boosting` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,405] The parameter `n_neurons_1` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,407] The parameter `n_neurons_2` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,408] The parameter `learning_rate` in Trial#98 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:50:54,613] Trial 98 finished with value: 0.8666666666666667 and parameters: {'use_Logistic Regression': False, 'use_Decision Tree': True, 'use_Random Forest': False, 'use_K-Nearest Neighbors': False, 'use_Support Vector Machine': True, 'use_AdaBoost': False, 'use_Gradient Boosting': False, 'n_layers': 3, 'n_neurons_0': 67, 'n_neurons_1': 54, 'n_neurons_2': 19, 'learning_rate': 'constant', 'learning_rate_init': 0.00626433536656886, 'alpha': 0.005048065716667474}. Best is trial 3 with value: 0.9.
# [W 2025-10-03 10:50:54,616] The parameter `use_Logistic Regression` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,618] The parameter `use_Decision Tree` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,619] The parameter `use_Random Forest` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,620] The parameter `use_K-Nearest Neighbors` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,620] The parameter `use_Support Vector Machine` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,620] The parameter `use_AdaBoost` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,621] The parameter `use_Gradient Boosting` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,622] The parameter `n_neurons_1` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,623] The parameter `n_neurons_2` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,623] The parameter `n_neurons_3` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [W 2025-10-03 10:50:54,624] The parameter `learning_rate` in Trial#99 is sampled independently using `RandomSampler` instead of `QMCSampler`, potentially degrading the optimization performance. This fallback happend because dynamic search space and `CategoricalDistribution` are not supported by `QMCSampler`. You can suppress this warning by setting `warn_independent_sampling` to `False` in the constructor of `QMCSampler` if this independent sampling is intended behavior.
# [I 2025-10-03 10:50:55,615] Trial 99 finished with value: 0.8833333333333333 and parameters: {'use_Logistic Regression': True, 'use_Decision Tree': True, 'use_Random Forest': False, 'use_K-Nearest Neighbors': True, 'use_Support Vector Machine': False, 'use_AdaBoost': False, 'use_Gradient Boosting': True, 'n_layers': 4, 'n_neurons_0': 44, 'n_neurons_1': 38, 'n_neurons_2': 72, 'n_neurons_3': 49, 'learning_rate': 'adaptive', 'learning_rate_init': 0.0001980956778550342, 'alpha': 0.00015963385442879435}. Best is trial 3 with value: 0.9.
#
# Best Meta Model Hyperparameters:
# {'activation': 'relu', 'alpha': 0.0003162277660168384, 'batch_size': 'auto', 'beta_1': 0.9, 'beta_2': 0.999, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (32, 16, 99, 80), 'learning_rate': 'constant', 'learning_rate_init': 0.0003162277660168384, 'max_fun': 15000, 'max_iter': 300, 'momentum': 0.9, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': 42, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}
#
# Selected Base Models for Stacking:
# - K-Nearest Neighbors
# - Support Vector Machine

# %%
# All Models Storage (including Stacking Model)
all_models = {
    'Logistic Regression': base_logistic_regression,
    'Decision Tree': base_decision_tree,
    'Random Forest': base_random_forest,
    'K-Nearest Neighbors': base_knn,
    'Support Vector Machine': base_svm,
    'AdaBoost': base_adaboost,
    'Gradient Boosting': base_gradient_boosting,
    'SEL-NNML': sel_nnml
}

# %% [markdown]
# ## **6. Model Evaluation**

# %% [markdown]
# This stage contains model evaluation on the test set, with details as follows:
# - `plot_evaluation_metrics()`: Shows the confusion matrix graph & scores for accuracy, precision, recall, and F1-Score
# - `Model Performance Comparison Plot`: Displays accuracy, precision, recall, F1-Score, and ROC AUC scores
# - `overfitting_index_plot()`: Shows the percentage of the difference between model scores on test data versus training data

# %%
# Single Model Evaluation Dashboard
def evaluation_metrics_plot(y_true, y_pred):
    # Calculate metrics
    cm = confusion_matrix(y_true, y_pred)
    metrics = {
        'Accuracy': accuracy_score(y_true, y_pred),
        'Precision': precision_score(y_true, y_pred),
        'Recall': recall_score(y_true, y_pred),
        'F1-Score': f1_score(y_true, y_pred),
    }
    metric_order = ['F1-Score', 'Recall', 'Precision', 'Accuracy']
    values = [metrics[name] for name in metric_order]

    fig = plt.figure(figsize=(10, 8))
    cm_pos = [0.08, 0.15, 0.53, 0.7]
    metrics_pos = [0.75, 0.15, 0.21, 0.7]

    # Confusion Matrix
    ax_cm = fig.add_axes(cm_pos)
    im = ax_cm.imshow(cm, cmap='Blues', interpolation='nearest', aspect='equal')
    cbar_ax = fig.add_axes([cm_pos[0] + cm_pos[2] + 0.02, cm_pos[1], 0.02, cm_pos[3]])
    fig.colorbar(im, cax=cbar_ax).ax.tick_params(labelsize=16)

    cm_pct = cm.astype(float) / cm.sum(axis=1, keepdims=True) * 100
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            count, pct = int(cm[i, j]), cm_pct[i, j]
            color = 'white' if count > cm.max() / 2 else 'black'
            ax_cm.text(j, i, f'{count}\n({pct:.1f}%)', ha='center', va='center',
                    color=color, fontsize=18, fontweight='bold', linespacing=1.1)

    ax_cm.set_xticks([0, 1])
    ax_cm.set_yticks([0, 1])
    ax_cm.set_xticklabels(['No\n(0)', 'Disease\n(1)'], fontsize=16)
    ax_cm.set_yticklabels(['No (0)', 'Disease (1)'], fontsize=16, rotation=90, va='center')
    ax_cm.set_xlabel('Predicted', fontsize=16, fontweight='bold')
    ax_cm.set_ylabel('Actual', fontsize=16, fontweight='bold')
    ax_cm.set_title('Confusion Matrix', fontsize=16, fontweight='bold', pad=10)
    ax_cm.set_ylim(1.5, -0.5)

    # Metrics Bar
    ax_metrics = fig.add_axes(metrics_pos)
    y_positions = np.arange(len(metric_order)) * 2
    bars = ax_metrics.barh(y_positions, values, height=0.8, color='#31688E', alpha=0.8)

    for bar, value in zip(bars, values):
        color = 'white' if value > 0.5 else 'black'
        x_pos = value - 0.02 if value > 0.5 else value + 0.02
        ha = 'right' if value > 0.5 else 'left'
        ax_metrics.text(x_pos, bar.get_y() + bar.get_height()/2, f'{value:.3f}',
                        ha=ha, va='center', fontsize=18, fontweight='bold', color=color)

    ax_metrics.set_xlim(-0.05, 1.05)
    ax_metrics.set_ylim(-0.8, len(metric_order) * 2 - 0.2)
    ax_metrics.set_xticks([0, 0.5, 1.0])
    ax_metrics.set_xticklabels(['0.0', '0.5', '1.0'], fontsize=16)
    ax_metrics.set_yticks(y_positions)
    ax_metrics.set_yticklabels(metric_order, fontsize=16, rotation=90, ha='left', va='center')
    ax_metrics.tick_params(axis='y', pad=15)
    ax_metrics.tick_params(axis='x', pad=8)
    ax_metrics.set_xlabel('Score', fontsize=16, fontweight='bold')
    ax_metrics.set_title('Performance Metrics', fontsize=16, fontweight='bold', pad=10)
    ax_metrics.grid(axis='x', alpha=0.3, linestyle='--')
    for spine in ['top', 'right', 'left']:
        ax_metrics.spines[spine].set_visible(False)
    ax_metrics.spines['bottom'].set_alpha(0.5)

    plt.show()

# %%
# Multiple Model Comparison Dashboard (for comparing all models)
def model_comparison_plot(models, x_test, y_test):
    metrics = {
        'Model': [],
        'Accuracy': [],
        'F1-Score': [],
        'Precision': [],
        'Recall': [],
        'AUC': []
    }
    
    # Map full names to short names
    short_names = {
        'Logistic Regression': 'LR',
        'Decision Tree': 'DT',
        'Random Forest': 'RF',
        'K-Nearest Neighbors': 'KNN',
        'Support Vector Machine': 'SVM',
        'AdaBoost': 'AdaBoost',
        'Gradient Boosting': 'Gradient Boosting',
        'SEL-NNML': 'SEL-NNML'
    }
    
    # Calculate metrics for each model
    for model_name, model in models.items():
        y_pred = model.predict(x_test)
        metrics['Model'].append(short_names[model_name])
        metrics['Accuracy'].append(accuracy_score(y_test, y_pred))
        metrics['F1-Score'].append(f1_score(y_test, y_pred))
        metrics['Precision'].append(precision_score(y_test, y_pred))
        metrics['Recall'].append(recall_score(y_test, y_pred))
        
        # Calculate AUC
        if hasattr(model, "predict_proba"):
            y_pred_proba = model.predict_proba(x_test)[:, 1]
        else:
            y_pred_proba = model.decision_function(x_test)
        fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
        roc_auc = auc(fpr, tpr)
        metrics['AUC'].append(roc_auc)
    
    # Convert metrics to DataFrame for sorting
    metrics_df = pd.DataFrame(metrics)
    
    fig, axes = plt.subplots(3, 2, figsize=(15, 18))
    fig.suptitle('Model Performance Comparison', fontsize=16, fontweight='bold') 
    
    # Helper function to plot sorted bar charts
    def plot_sorted_bar_chart(ax, metric_name):
        sorted_df = metrics_df.sort_values(by=metric_name, ascending=False)
        colors = ['tab:orange' if model == 'SEL-NNML' else 'tab:blue' for model in sorted_df['Model']]
        ax.bar(sorted_df['Model'], sorted_df[metric_name], color=colors)
        ax.set_title(metric_name)
        ax.set_ylabel('Score')
        ax.set_ylim([0, 1])
        ax.set_xticks(range(len(sorted_df['Model'])))
        ax.set_xticklabels(sorted_df['Model'], rotation=30, ha='center')
        for i, v in enumerate(sorted_df[metric_name]):
            ax.text(i, v + 0.01, f'{v:.3f}', ha='center')

    # Plot each metric
    plot_sorted_bar_chart(axes[0, 0], 'Accuracy')
    plot_sorted_bar_chart(axes[0, 1], 'F1-Score')
    plot_sorted_bar_chart(axes[1, 0], 'Precision')
    plot_sorted_bar_chart(axes[1, 1], 'Recall')
    
    # ROC Curve
    ax_roc = axes[2, 0]
    for model_name, model in models.items():
        if hasattr(model, "predict_proba"):
            y_pred_proba = model.predict_proba(x_test)[:, 1]
        else:
            y_pred_proba = model.decision_function(x_test)
        fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
        roc_auc = auc(fpr, tpr)
        ax_roc.plot(fpr, tpr, lw=2, label=f'{short_names[model_name]} (AUC = {roc_auc:.3f})')
    ax_roc.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
    ax_roc.set_xlim([0.0, 1.0])
    ax_roc.set_ylim([0.0, 1.05])
    ax_roc.set_title('Receiver Operating Characteristic')
    ax_roc.set_xlabel('False Positive Rate')
    ax_roc.set_ylabel('True Positive Rate')
    ax_roc.legend(loc="lower right")
    
    # Bar chart for AUC
    plot_sorted_bar_chart(axes[2, 1], 'AUC')

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %%
def overfitting_index_plot(all_models, x_train, y_train, x_test, y_test):
    metrics = ['Accuracy', 'F1-Score', 'Precision', 'Recall']
    overfitting_indices = {metric: [] for metric in metrics}

    for _, model in all_models.items():
        y_train_pred = model.predict(x_train)
        y_test_pred = model.predict(x_test)
        overfitting_indices['Accuracy'].append(abs(accuracy_score(y_train, y_train_pred) - accuracy_score(y_test, y_test_pred)) / accuracy_score(y_train, y_train_pred) * 100)
        overfitting_indices['F1-Score'].append(abs(f1_score(y_train, y_train_pred) - f1_score(y_test, y_test_pred)) / f1_score(y_train, y_train_pred) * 100)
        overfitting_indices['Precision'].append(abs(precision_score(y_train, y_train_pred) - precision_score(y_test, y_test_pred)) / precision_score(y_train, y_train_pred) * 100)
        overfitting_indices['Recall'].append(abs(recall_score(y_train, y_train_pred) - recall_score(y_test, y_test_pred)) / recall_score(y_train, y_train_pred) * 100)

    overfitting_df = pd.DataFrame(overfitting_indices, index=all_models.keys())

    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    fig.suptitle('Overfitting Index for All Metrics', fontsize=16, fontweight='bold')

    def get_bar_colors(models, highlight_model='SEL-NNML', default_color='tab:blue', highlight_color='tab:orange'):
        return [highlight_color if model == highlight_model else default_color for model in models]

    # Accuracy
    overfitting_df_sorted = overfitting_df.sort_values(by='Accuracy', ascending=False)
    axes[0, 0].bar(overfitting_df_sorted.index, overfitting_df_sorted['Accuracy'], 
                    color=get_bar_colors(overfitting_df_sorted.index))
    axes[0, 0].set_title('Accuracy Overfitting Index')
    axes[0, 0].set_ylabel('Overfitting Index (%)')
    axes[0, 0].set_ylim([0, 100])
    axes[0, 0].tick_params(axis='x', rotation=30)
    for i, v in enumerate(overfitting_df_sorted['Accuracy']):
        axes[0, 0].text(i, v + 1, f'{v:.2f}', ha='center')

    # F1-Score
    overfitting_df_sorted = overfitting_df.sort_values(by='F1-Score', ascending=False)
    axes[0, 1].bar(overfitting_df_sorted.index, overfitting_df_sorted['F1-Score'], 
                    color=get_bar_colors(overfitting_df_sorted.index))
    axes[0, 1].set_title('F1-Score Overfitting Index')
    axes[0, 1].set_ylabel('Overfitting Index (%)')
    axes[0, 1].set_ylim([0, 100])
    axes[0, 1].tick_params(axis='x', rotation=30)
    for i, v in enumerate(overfitting_df_sorted['F1-Score']):
        axes[0, 1].text(i, v + 1, f'{v:.2f}', ha='center')

    # Precision
    overfitting_df_sorted = overfitting_df.sort_values(by='Precision', ascending=False)
    axes[1, 0].bar(overfitting_df_sorted.index, overfitting_df_sorted['Precision'], 
                    color=get_bar_colors(overfitting_df_sorted.index))
    axes[1, 0].set_title('Precision Overfitting Index')
    axes[1, 0].set_ylabel('Overfitting Index (%)')
    axes[1, 0].set_ylim([0, 100])
    axes[1, 0].tick_params(axis='x', rotation=30)
    for i, v in enumerate(overfitting_df_sorted['Precision']):
        axes[1, 0].text(i, v + 1, f'{v:.2f}', ha='center')

    # Recall
    overfitting_df_sorted = overfitting_df.sort_values(by='Recall', ascending=False)
    axes[1, 1].bar(overfitting_df_sorted.index, overfitting_df_sorted['Recall'], 
                    color=get_bar_colors(overfitting_df_sorted.index))
    axes[1, 1].set_title('Recall Overfitting Index')
    axes[1, 1].set_ylabel('Overfitting Index (%)')
    axes[1, 1].set_ylim([0, 100])
    axes[1, 1].tick_params(axis='x', rotation=30)
    for i, v in enumerate(overfitting_df_sorted['Recall']):
        axes[1, 1].text(i, v + 1, f'{v:.2f}', ha='center')

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %% [markdown]
# ### **6.1 Single Model Evaluation**

# %%
# Show SEL-NNML Evaluation Metrics
y_pred_stack = sel_nnml.predict(X_test)
evaluation_metrics_plot(y_test, y_pred_stack)

# %%
# Show SEL-NNM: all fold scores with mean and std 
sel_nnml_cv_scores = cross_val_score(sel_nnml, X_train, y_train, cv=CV_FOLDS, scoring='accuracy', n_jobs=N_JOBS)
print(f'SEL-NNML CV Accuracy Scores [Fold 1, Fold 2, ..., Fold n]: {sel_nnml_cv_scores}')
print(f'Mean: {sel_nnml_cv_scores.mean():.4f}')
print(f'Standard Deviation: {sel_nnml_cv_scores.std():.4f}')
# Out:
# SEL-NNML CV Accuracy Scores [Fold 1, Fold 2, ..., Fold n]: [0.83333333 0.77083333 0.82978723 0.70212766 0.82978723]
# Mean: 0.7932
# Standard Deviation: 0.0512

# %%
# Show SELL-NNML Training Time
Total_training_time = base_models_training_time + meta_model_training_time
print(f'Base Models Tuning & Training Time: {base_models_training_time:.2f} seconds')
print(f'Meta Model Tuning & Training Time: {meta_model_training_time:.2f} seconds')
print(f'Total SEL-NNML Tuning & Training Time: {Total_training_time:.2f} seconds')
# Out:
# Base Models Tuning & Training Time: 53.62 seconds
# Meta Model Tuning & Training Time: 70.18 seconds
# Total SEL-NNML Tuning & Training Time: 123.80 seconds

# %% [markdown]
# ### **6.2 Multiple Model Evaluation**

# %%
model_comparison_plot(all_models, X_test, y_test)

# %%
overfitting_index_plot(all_models, X_train, y_train, X_test, y_test)
